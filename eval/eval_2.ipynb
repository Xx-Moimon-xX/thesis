# %% [markdown]
# # Eval for Codex

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: requests in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 1)) (2.32.4)
# Requirement already satisfied: python-dotenv in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: dotenv in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 3)) (0.9.9)
# Requirement already satisfied: pandas in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 4)) (2.3.0)
# Requirement already satisfied: pytest in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 5)) (8.4.1)
# Requirement already satisfied: boto3 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 6)) (1.38.42)
# Requirement already satisfied: langchain_community in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 7)) (0.3.26)
# Requirement already satisfied: ipywidgets in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 8)) (8.1.7)
# Requirement already satisfied: IPython in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 9)) (9.3.0)
# Requirement already satisfied: ipydatagrid in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 10)) (1.4.0)
# Requirement already satisfied: itables in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 11)) (2.4.2)
# Requirement already satisfied: importlib in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from -r requirements.txt (line 12)) (1.0.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from requests->-r requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from requests->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from requests->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from requests->-r requirements.txt (line 1)) (2025.6.15)
# Requirement already satisfied: numpy>=1.26.0 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from pandas->-r requirements.txt (line 4)) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from pandas->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from pandas->-r requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from pandas->-r requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: iniconfig>=1 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from pytest->-r requirements.txt (line 5)) (2.1.0)
# Requirement already satisfied: packaging>=20 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from pytest->-r requirements.txt (line 5)) (24.2)
# Requirement already satisfied: pluggy<2,>=1.5 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from pytest->-r requirements.txt (line 5)) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from pytest->-r requirements.txt (line 5)) (2.19.2)
# Requirement already satisfied: botocore<1.39.0,>=1.38.42 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from boto3->-r requirements.txt (line 6)) (1.38.42)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from boto3->-r requirements.txt (line 6)) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from boto3->-r requirements.txt (line 6)) (0.13.0)
# Requirement already satisfied: six>=1.5 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from langchain_community->-r requirements.txt (line 7)) (0.3.66)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from langchain_community->-r requirements.txt (line 7)) (0.3.26)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from langchain_community->-r requirements.txt (line 7)) (2.0.41)
# Requirement already satisfied: PyYAML>=5.3 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from langchain_community->-r requirements.txt (line 7)) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from langchain_community->-r requirements.txt (line 7)) (3.12.13)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from langchain_community->-r requirements.txt (line 7)) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from langchain_community->-r requirements.txt (line 7)) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from langchain_community->-r requirements.txt (line 7)) (2.10.0)
# Requirement already satisfied: langsmith>=0.1.125 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from langchain_community->-r requirements.txt (line 7)) (0.4.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from langchain_community->-r requirements.txt (line 7)) (0.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 7)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 7)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 7)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 7)) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 7)) (6.5.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 7)) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 7)) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community->-r requirements.txt (line 7)) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community->-r requirements.txt (line 7)) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from langchain<1.0.0,>=0.3.26->langchain_community->-r requirements.txt (line 7)) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from langchain<1.0.0,>=0.3.26->langchain_community->-r requirements.txt (line 7)) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain_community->-r requirements.txt (line 7)) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain_community->-r requirements.txt (line 7)) (4.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain_community->-r requirements.txt (line 7)) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain_community->-r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain_community->-r requirements.txt (line 7)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain_community->-r requirements.txt (line 7)) (0.4.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community->-r requirements.txt (line 7)) (1.1.0)
# Requirement already satisfied: comm>=0.1.3 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from ipywidgets->-r requirements.txt (line 8)) (0.2.2)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from ipywidgets->-r requirements.txt (line 8)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from ipywidgets->-r requirements.txt (line 8)) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from ipywidgets->-r requirements.txt (line 8)) (3.0.15)
# Requirement already satisfied: decorator in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from IPython->-r requirements.txt (line 9)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from IPython->-r requirements.txt (line 9)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from IPython->-r requirements.txt (line 9)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from IPython->-r requirements.txt (line 9)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from IPython->-r requirements.txt (line 9)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from IPython->-r requirements.txt (line 9)) (3.0.51)
# Requirement already satisfied: stack_data in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from IPython->-r requirements.txt (line 9)) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython->-r requirements.txt (line 9)) (0.2.13)
# Requirement already satisfied: bqplot>=0.11.6 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from ipydatagrid->-r requirements.txt (line 10)) (0.12.45)
# Requirement already satisfied: py2vega>=0.5 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from ipydatagrid->-r requirements.txt (line 10)) (0.6.1)
# Requirement already satisfied: traittypes>=0.0.6 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from bqplot>=0.11.6->ipydatagrid->-r requirements.txt (line 10)) (0.2.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from jedi>=0.16->IPython->-r requirements.txt (line 9)) (0.8.4)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from langsmith>=0.1.125->langchain_community->-r requirements.txt (line 7)) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from langsmith>=0.1.125->langchain_community->-r requirements.txt (line 7)) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from langsmith>=0.1.125->langchain_community->-r requirements.txt (line 7)) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from langsmith>=0.1.125->langchain_community->-r requirements.txt (line 7)) (0.23.0)
# Requirement already satisfied: anyio in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community->-r requirements.txt (line 7)) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community->-r requirements.txt (line 7)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community->-r requirements.txt (line 7)) (0.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from pexpect>4.3->IPython->-r requirements.txt (line 9)) (0.7.0)
# Requirement already satisfied: gast<0.5,>=0.4.0 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from py2vega>=0.5->ipydatagrid->-r requirements.txt (line 10)) (0.4.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from stack_data->IPython->-r requirements.txt (line 9)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from stack_data->IPython->-r requirements.txt (line 9)) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/cxnpl/cxnpl/baizantium/.venv/lib/python3.13/site-packages (from stack_data->IPython->-r requirements.txt (line 9)) (0.2.3)

# %%
import requests
import json
import pandas as pd
from dotenv import load_dotenv
import os
import ipywidgets as widgets
from IPython.display import display
from ipydatagrid import DataGrid
from itables import show
import importlib
import glob

# %%
import evaluation_prompts.eval_prompt2 as eval_prompt
importlib.reload(eval_prompt)
print(eval_prompt.evaluation_prompt)
# Out:
# You are an expert evaluator assessing how well an LLM response matches expected responses.
#
# **EVALUATION DATA:**
# [BEGIN DATA]
# [Prompt]: {prompt}
# [LLM Response]: {response}
# [Expected Response 1]: {expected_response_1}
# [Expected Response 2]: {expected_response_2}
# [Expected Response 3]: {expected_response_3}
# [END DATA]
#
# **TASK:**
# 1. Compare the LLM response to each expected response and identify which ONE it most closely matches
# 2. Score the match quality using this 5-point scale:
#    - **5 (Excellent):** Same core meaning, even if worded differently
#    - **4 (Good):** Minor differences only (slight wording variations)
#    - **3 (Partial):** Significant differences affecting clarity/completeness
#    - **2 (Poor):** Some relation but fails to convey correct meaning
#    - **1 (No Match):** No meaningful match in meaning/content/intent
# 3. Determine acceptance: scores 3-5 = "yes", scores 1-2 = "no"
#
# **CRITICAL OUTPUT REQUIREMENTS:**
# - You MUST return ONLY a JSON object with EXACTLY these 4 fields
# - Use EXACTLY these field names (case-sensitive): "selected_expected_response", "score", "answer", "reasoning"
# - DO NOT add any other fields or modify field names
# - DO NOT include any text before or after the JSON
# - DO NOT include markdown code blocks or formatting
# - DO NOT include a comma after the last field in the JSON object.
# - The value of the "reasoning" field should be a string, with no extra characters (such as commas, periods, or whitespace) after the closing quotation mark.
#
# **REQUIRED JSON FORMAT:**
# {{
#     "selected_expected_response": "<exact copy of the expected response you selected>",
#     "score": <integer from 1 to 5>,
#     "answer": "<exactly 'yes' or 'no' in lowercase>",
#     "reasoning": "<2-3 sentence explanation comparing LLM response to selected expected response>"
# }}
#
# Focus on semantic meaning over exact wording. When uncertain between scores, choose the lower score.
#
# Return only the JSON object now:

# %%
import sys
sys.path.append('/path/to/eval/evaluation_prompts')
load_dotenv(override=True)
BASE_URL = "http://localhost:3100/api"
API_KEY = os.environ.get("OPENWEBUI_API_KEY", "")
headers = {"Authorization": f"Bearer {API_KEY}", "Content-Type": "application/json"}

# %% [markdown]
# ## Getting all Models
# Testing if we can fetch models from the API

# %%
try:
    response = requests.get(f"{BASE_URL}/models", headers=headers)
    response.raise_for_status()
    json_data = response.json()
    
    # Convert to DataFrame 
    if json_data and 'data' in json_data:
        models_df = pd.DataFrame(json_data['data'])
        print(models_df)
except requests.exceptions.RequestException as e:
    print(f"Error fetching models: {e}")
# Out:
#                                                id     created object owned_by  \
# 0                            amazon.nova-pro-v1:0  1751509746  model   openai
# 1                           amazon.nova-lite-v1:0  1751509746  model   openai
# 2                          amazon.nova-micro-v1:0  1751509746  model   openai
# 3  apac.anthropic.claude-3-5-sonnet-20240620-v1:0  1751509746  model   openai
# 4  apac.anthropic.claude-3-5-sonnet-20241022-v2:0  1751509746  model   openai
# 5  apac.anthropic.claude-3-7-sonnet-20250219-v1:0  1751509746  model   openai
# 6    apac.anthropic.claude-sonnet-4-20250514-v1:0  1751509746  model   openai
#
#   connection_type                                            name  \
# 0        external                            amazon.nova-pro-v1:0
# 1        external                           amazon.nova-lite-v1:0
# 2        external                          amazon.nova-micro-v1:0
# 3        external  apac.anthropic.claude-3-5-sonnet-20240620-v1:0
# 4        external  apac.anthropic.claude-3-5-sonnet-20241022-v2:0
# 5        external  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 6        external    apac.anthropic.claude-sonnet-4-20250514-v1:0
#
#                                               openai  urlIdx actions filters  \
# 0  {'id': 'amazon.nova-pro-v1:0', 'created': 1751...       0      []      []
# 1  {'id': 'amazon.nova-lite-v1:0', 'created': 175...       0      []      []
# 2  {'id': 'amazon.nova-micro-v1:0', 'created': 17...       0      []      []
# 3  {'id': 'apac.anthropic.claude-3-5-sonnet-20240...       0      []      []
# 4  {'id': 'apac.anthropic.claude-3-5-sonnet-20241...       0      []      []
# 5  {'id': 'apac.anthropic.claude-3-7-sonnet-20250...       0      []      []
# 6  {'id': 'apac.anthropic.claude-sonnet-4-2025051...       0      []      []
#
#   tags                                               info
# 0   []                                                NaN
# 1   []                                                NaN
# 2   []                                                NaN
# 3   []                                                NaN
# 4   []                                                NaN
# 5   []                                                NaN
# 6   []  {'id': 'apac.anthropic.claude-sonnet-4-2025051...

# %% [markdown]
# Choose a model going ahead to the eval.

# %%
model_options = models_df['id'].tolist()

model_dropdown = widgets.Dropdown(
    options=model_options,
    value="apac.anthropic.claude-3-7-sonnet-20250219-v1:0",  # default selection
    description='Model:',
    disabled=False,
)

display(model_dropdown)
# Out:
# Dropdown(description='Model:', index=5, options=('amazon.nova-pro-v1:0', 'amazon.nova-lite-v1:0', 'amazon.nova…

# %%
model = model_dropdown.value
print("You selected:", model)
# Out:
# You selected: apac.anthropic.claude-3-7-sonnet-20250219-v1:0

# %% [markdown]
# ## Getting all queries and Passing to LLM
# Getting all prompts from data.csv file

# %%
data_dir = 'data'
data_files = [f for f in os.listdir(data_dir) if os.path.isfile(os.path.join(data_dir, f))]
print(data_files)
# Out:
# ['data2.csv', 'data.csv']

# %%
dataset_dropdown = widgets.Dropdown(
    options=data_files,
    value="data2.csv",  # default selection
    description='Dataset:',
    disabled=False,
)
display(dataset_dropdown)
# Out:
# Dropdown(description='Dataset:', options=('data2.csv', 'data.csv'), value='data2.csv')

# %%
print(dataset_dropdown.value)
# Out:
# data2.csv

# %%
try: 
    file_path = os.path.join(data_dir, dataset_dropdown.value)
    prompts_df = pd.read_csv(file_path)
    prompt_expresponse_tuple = prompts_df.values.tolist()
except FileNotFoundError:
    print(f"Error: data/{dataset_dropdown.value} not found.")
    prompt_expresponse_tuple = []

# %%
# print(prompt_expresponse_tuple)
for prompt, expected_response1, expected_response2, expected_response3 in prompt_expresponse_tuple:
    print(prompt, expected_response1, expected_response2, expected_response3)
# Out:
# List all channels in the workspace Here are all the channels in the Slack workspace:
#
# Main Company Channels:
# #general (201 members) - Main company-wide channel for announcements and team conversations
# #random (199 members) - Casual conversation and team jokes
# #help-it (196 members) - IT related queries
# #help-hr (191 members) - HR related queries
# #help-legal-risk-compliance (97 members) - Legal/risk/compliance queries
# Engineering & Tech Channels:
# #all-devs (132 members) - All engineers company-wide
# #plz-review (109 members) - Code review requests
# #eng-backend (102 members) - Backend engineering discussions
# #fe-gang (89 members) - Frontend engineering team
# #guild-backend (33 members) - Backend guild
# #guild-devx (132 members) - Developer experience guild
# Product & Operations:
# #product (76 members) - Product management discussions
# #operations-service-model (4 members) - Operations organization
# #prod-onboarding (69 members) - Production onboarding
# #incident-response (97 members) - Incident response FAQ
# Business & Finance:
# #finance (37 members) - Finance workstream
# #business-team (4 members) - Business team discussions
# #intel (96 members) - Competitor and client intelligence
# #client-implementation-and-governance (3 members) - Client work
# Team Squads:
# #squad-users (102 members) - User-focused squad
# #squad-lending (95 members) - Lending team
# #squad-mese (21 members) - Payments, Payees, Cards squad
# #squad-platform (106 members) - Platform squad
# #squad-data (98 members) - Data team
# Social & Fun:
# #pet-pics (51 members) - Pet photos
# #foodlovers (44 members) - Food discussions
# #good-reads (41 members) - Blog post recommendations
# #run-club (41 members) - Running club
# #gains-club (20 members) - Gym and fitness
# #coffee-buddies (49 members) - Coffee meetups
# Office Locations:
# #sydney-office (101 members) - Sydney office coordination
# #melbourne-office (8 members) - Melbourne office
# #india-office (58 members) - India office
# The workspace has a total of 580+ channels covering everything from technical projects and production alerts to social clubs and office coordination. The channels are well-organized with clear naming conventions (prefixes like proj-, squad-, help-, vendor-, etc.) to help users find relevant discussions. nan nan
# Show me all public channels Here are all the public channels available in your Slack workspace:
#
# General Channels
# #general (202 members) - Main workspace channel for announcements and team-wide conversations
# #random (200 members) - For everything else - team jokes, ideas, and GIFs
# Core Business & Operations
# #business-team (4 members) - Business team discussions, propositions, product, roadmap
# #business-development (4 members) - Business development activities
# #client-solutions (3 members) - Client solutions and differentiator discussions
# #operations-service-model (4 members) - Operations organization and delivery
# #pmo (1 member) - Project Management Office
# #product-operations (88 members) - Product operations discussions
# Engineering & Development
# #all-devs (132 members) - All engineers company-wide
# #eng-backend (102 members) - Backend engineering discussions
# #fe-gang (90 members) - Frontend engineering discussions and PR review requests
# #tech (1 member) - General tech discussions
# #design (52 members) - Design updates, feedback, and questions
# Squads & Teams
# #squad-mese (21 members) - Payments, Payees, Cards Squad
# #squad-users (102 members) - User onboarding squad
# #squad-lending (95 members) - Lending squad
# #squad-platform (107 members) - Platform squad
# #squad-txb (125 members) - Transaction banking squad
# #squad-data (98 members) - Data team requests and discussions
# #squad-prod-ops (119 members) - Production operations support
# Help & Support Channels
# #help-it (197 members) - IT related queries
# #help-hr (192 members) - HR related queries
# #help-legal-risk-compliance (97 members) - Legal/risk/compliance queries
# #help-engineering (28 members) - Engineering related queries
# #help-office-syd (64 members) - Sydney office related help
# Production & Monitoring
# #prod-lending (75 members) - Production lending issues
# #prod-txb (52 members) - Production TXB issues/discussions
# #prod-platform-alerts (30 members) - Production platform alerts
# #incident-response (98 members) - Incidents FAQs and response
# #major-incident-comms (73 members) - Major incidents internal communications
# Social & Interest Groups
# #pet-pics (54 members) - Pet photos
# #foodlovers (43 members) - Food tips, recipes, events, news
# #run-club (41 members) - Running club
# #gains-club (20 members) - Gym and fitness related
# #rock-enthusiasts (13 members) - Rock climbing
# #formula-1-club (16 members) - Formula 1 discussions (no spoilers!)
# #swim-club (20 members) - Swimming club
# #cxnpl-tennis-club (14 members) - Tennis club
# There are 502 total public channels in your workspace, covering everything from core business operations to social activities and specialized project work. nan nan
# Post 'Hello team! From eval framework here.' to channel C08UFS9HMCN I successfully posted the message \Hello team! From eval framework here.\" to channel C08UFS9HMCN (which is the ai-slackbot-testing channel) at the timestamp..." nan nan
# Add heart reaction to message at timestamp 1750300317.785949 in channel C08UFS9HMCN Great! I've successfully added a heart reaction (__) to the message at timestamp 1750300317.785949 in channel C08UFS9HMCN. The reaction has been added successfully. It looks like a heart reaction has already been added to this message. The Slack API returned an "already_reacted" error, which means either you or someone else has already reacted to this message with a heart emoji.
#
# If you'd like to try a different reaction emoji, just let me know which one you'd prefer! nan
# Reply to thread 1750300317.785949 in channel C08UFS9HMCN with 'Thanks for the update!' Perfect! I've successfully replied to the thread with "Thanks for the update!" in channel C08UFS9HMCN. The reply was posted at timestamp 1751251060.214489 and is now part of the thread that started with message 1750300317.785949. nan nan
# Get all replies from thread 1750300317.785949 in channel C08UFS9HMCN Here are all the replies in the thread starting with timestamp 1750300317.785949:
#
# Thread Summary
# Total replies: 6 messages (including the original)
# Thread participants: 2 users
# Latest reply: Just posted (1751251060.214489)
#
# Messages in order:
# Original Message (1750300317.785949) - by Codex bot:
# __ Random Message Alert! __
# Fun fact about octopuses having three hearts and blue blood! ____
# Testing AI chatbot functionality
# Written on behalf of Alan Nguyen
# Reactions: __ (2), __ (1), __ (1)
# Reply 1 (1750743854.095189) - by User U08FUTB4QLC:
# "Awesome, thats so cool!"
# Reply 2 (1750743906.601929) - by Codex bot:
# "Thanks for the update!"
# Written on behalf of Mohitha Mohan
# Reply 3 (1750920418.327549) - by Codex bot:
# "Thanks for the update!"
# Reply 4 (1750922035.122979) - by Codex bot:
# "Thanks for the update!"
# Reply 5 (1751251060.214489) - by Codex bot:
# "Thanks for the update!" (this is the reply we just posted)
# The thread shows good engagement with the original fun fact message, and several "Thanks for the update!" replies from the Codex bot. nan nan
# Show me all the users in the workspace Here are all the users in your Slack workspace:
#
# Workspace Members (160 total users)
# Leadership & Management:
#
# Cameron Meindl (@cameron_meindl) - Field CTO Constantinople
# Keerthi Iyengar (@keerthi_iyengar) - Chief Operating Officer
# Danielle Ross (@danielle_ross) - Head of People
# Luke Raven (@luke_raven) - Head of FinCrime & Fraud
# Tony Bolcina (@tony_bolcina) - Head of Design
# Engineering Managers:
#
# Maciej Adamczak (@maciej_adamczak) - UX Squad: Platform - Engineering Manager
# Kausthubh Adhikari (@kausthubh_adhikari) - Engineering Manager - UX Squad Mobile
# Rohit Khandelwal (@rohit_khandelwal) - Engineering Manager - TXB squad
# Senior Engineers & Technical Leads:
#
# Oscar Fawkes (@oscar_fawkes) - GAI TL
# Evan Kohilas (@evan_kohilas) - Senior Software Engineer on the Platform Squad
# Shubham Ranu (@shubham_ranu) - Senior Software Engineer - Users & Onboarding
# Utkarsh Sharma (@utkarsh_sharma) - Senior Software Engineer
# Mrinal Pradhan (@mrinal_pradhan) - Senior Software Engineer
# Software Engineers:
#
# Campbell Wang (@campbell_wang) - Junior Software Engineer (with quite the title collection! __)
# Meraj Ahmad (@meraj_ahmad) - Software Engineering - Users & Onboarding
# Nitin Mishra (@nitin_mishra) - Software Engineer
# Dhairya Punjabi (@dhairya_punjabi) - Senior Software Developer
# Ishaank Gupta (@ishaank_gupta) - Senior FE @ Onboarding
# Aniket Chaudhary (@aniket_chaudhary) - Senior FE @txb (and water connoisseur! __)
# ThoughtWorks Team:
#
# Neha Aggarwal, Shubham Kumar, Rishi Dahiya, Ankit Chaudhary, Shivam Kapoor, Komal Bansal, Umair Shaik, Suresh Kumar Putchala, Manish Gupta, Aashita Trehan, Bhumanyu Kumar, Brijesh Gajjar, Adarsh Jegadeesan, Camilo Diaz, Luke McCartin, Trupthi Mahesh, Arun Chakkaravarthi M, Praveen Prasannan
# Specialists & Other Roles:
#
# Alan Nguyen (@alan_nguyen) - Forward deployed prompt engineer __
# Jeremy Smith (@jeremy_smith) - Crab __
# Blake Belcastro (@blake_belcastro) - Chief Widget Officer
# Alec Zhang (@alec_zhang) - Where's the lamb sauce
# Theon Ho (@theon_ho) - Laksa King
# Andy Truong (@andy_truong) - Progamer
# Gautham Ontri (@gautham_ontri) - Internet Mechanic
# Jordan Yoong (@jordan_yoong) - Internet security guard
# Benjamin Staite (@benjamin_staite) - Head of Basketball Operations
# Fun Titles & Personalities:
#
# Stella Reeve (@stella_reeve) - Product Ops (his name is Beans)
# Lawrence Shi (@lawrence_shi) - i live for hardstyle baby
# Ido Zamir (@ido_zamir) - Old Man with Soup
# Lachlan McGrath (@lachlan_mcgrath) - Banh Mi Enthusiast
# Grace Gleeson (@grace_gleeson) - CXNPL Botanist
# Hayley Rodgers (@hayley_rodgers) - kitchen fairy
# Fergus Charles (@fergus_charles) - In house chef _____
# Alexandra Maher (@alexandra_maher) - live laugh loan no longer
# Kaito Nakamichi (@kaito_nakamichi) - average volatility enthusiast
# Heather Prenter (@heather_prenter) - Heather from Credit
# Arun Manivannan (@arun_manivannan) - master of awkward conversations
# And many more talented individuals across various teams including Data Analytics, Legal, Talent Acquisition, Client Delivery, AWS, and other specialized roles!
#
# The workspace has a great mix of technical talent, leadership, and some wonderfully creative job titles! __ nan nan
# Get profile details for user U08FUTB4QLC Here are the detailed profile information for user U08FUTB4QLC:
#
# Profile Details for Mohitha Mohan
# Basic Information:
#
# Real Name: Mohitha Mohan
# Display Name: Mohitha Mohan
# Email: Mohitha@cxnpl.com
# User ID: U08FUTB4QLC
# Username: @mohitha_mohan
# Profile Status:
#
# Title: (Not specified)
# Status Text: (Currently empty)
# Status Emoji: (None set)
# Contact Information:
#
# Phone: (Not provided)
# Skype: (Not provided)
# Profile Images:
#
# Has Custom Image: Yes
# Avatar Hash: fb39e0e7d7e7
# Profile Image: Available in multiple sizes (24px to 1024px)
# Additional Details:
#
# First Name: Mohitha
# Last Name: Mohan
# Huddle State: Default (not in a huddle)
# This user appears to be one of the team members at CXNPL (based on their email domain) and was one of the participants in the thread we looked at earlier, where they replied "Awesome, thats so cool!" to the octopus fun fact message. nan nan
# Search for messages containing 'mcp server' Here are the search results for messages containing 'mcp server':
#
# Search Results: 'mcp server' (10 matches found)
# Recent MCP Server Development Activity
# Mohitha Mohan (Jan 19) in #squad-ai-internal:
# "Okay got the mock boshporus mcp server to work on open webui through the docker container yay. The only thing I forgot to mention is that you do have to connect your tool server to open webui manually (user tool server) as seen here..."
# Successfully got Bosphorus MCP server working with Open WebUI
# Notes about manual tool server connection requirements
# Jeremy Smith (Jan 26) in #squad-ai-internal:
# "All MCP servers in a single MCPO container and all tools working (still. They were all working in Mohitha's original PR)"
# GitLab merge request for consolidating all MCP servers
# Needs approval from Mohitha or Oscar
# Jeremy Smith (Feb 3) in #squad-ai-internal:
# "Holy hell that's an advanced MCP server. Needs approval but wow, handling auth flow properly via the chat is pretty cool"
# Impressed with advanced MCP server capabilities, especially auth flow handling
# Mohitha Mohan (Feb 10) in #squad-ai-internal:
# "Found this jira tool bug on mainmerge. Looks like its the same empty string error, we might have to clean up the atlassian mcp server code too?"
# Bug report related to Atlassian MCP server
# Empty string error affecting Jira tools
# Jeremy Smith (Feb 3) in #ai-cxnpl:
# "MS 365 MCP Server? Currently using it with desktop apps (not Codex) as there's a bug/incompatibility..."
# Requesting access approval for MS 365 MCP Server
# Working on compatibility issues with Codex
# Mohitha Mohan (Feb 6) in #squad-ai-internal:
# "Awesome I got the mcp server tool to return only a section of the metadata and increased the default limit of channel items to 1000..."
# Performance improvements to MCP server
# Better performance on Cursor and Claude
# Alan Nguyen (Jan 26) in #squad-ai:
# "The AI squad is about to release an Internal AI chatbot + our own MCP servers (incl atlassian, slack). We're aiming to create a systematic approach..."
# Announcement about upcoming AI chatbot release
# MCP servers for Atlassian and Slack
# Link to documentation space
# Mohitha Mohan (Feb 2) in #squad-ai-internal:
# "The whole remote MCPs definitely didn't have this much documentation when I was looking into it like a month ago... It also looks like they archived the slack mcp server we were using"
# Commentary on rapid MCP development pace
# Notice that their Slack MCP server was archived
# Jeremy Smith (Dec 18) in #squad-ai-internal:
# [Long technical log about MCP server configuration]
# Detailed server startup logs showing multiple MCP servers being configured
# Includes: slack, atlassian, bosphorus, slack-mutated, microsoft365, spinach, gitlab
# Shows some startup errors with Atlassian server
# Summary
# The team has been actively working on:
#
# Multiple MCP servers: Atlassian/Jira, Slack, Microsoft 365, Bosphorus, GitLab
# Integration challenges: Working on compatibility with Open WebUI and Codex
# Performance optimizations: Improving metadata handling and response limits
# Auth flow handling: Advanced authentication capabilities
# Documentation: Creating systematic approaches for MCP server development
# The conversation shows they're building a comprehensive internal AI platform with multiple integrated tools via MCP servers! ____ nan nan
# Get recent messages from the ytg channel I've successfully retrieved the recent messages from the ytg channel. Here's a summary of the recent activity:
#
# Recent Messages from the YTG Channel
# The ytg channel appears to be a social group for women at the company ("Young, Talented, Gorgeous" or similar). Here are the key recent activities:
#
# Most Recent Messages:
# Upcoming Dinner Plans - Someone mentioned wrapping up a call and leaving the office soon, with people confirming their attendance for "tonight" with checking hands and raised hand reactions.
# Restaurant Booking - Ross has booked a place and shared an image, with people reacting positively to indicate they're interested in attending.
# Date Planning - Discussion about May 14th working for most people, with many positive reactions.
# Dinner Suggestion - A message about it being time for another dinner, which received lots of heart reactions and positive responses.
# Nail Salon Recommendation - Someone shared a location near the office for nail services (blancblue nail & beauty in Haymarket).
# Social Sports Information - A PSA about Urban Rec offering free registration for women to join social sports teams in Sydney.
# Bottomless Brunch Planning - Multiple detailed messages about organizing a "CXNPLadies" bottomless brunch at Ho Jiak Town Hall, including:
# Menu details and pricing ($88 each for 9 courses + unlimited drinks)
# Poll for date selection (Feb 14 dinner vs Feb 15 brunch)
# Discussion about alternative venues for those not wanting alcohol/expensive options
# Promotions Celebration - Congratulatory messages celebrating promotions and role changes of several women in the group.
# Fitness/Sports - Messages about borrowing workout clothes and charity walk participation.
# The channel appears very active with social planning, workplace celebrations, and mutual support among the female employees. nan nan
# Post 'Meeting in 5 minutes - from eval framework' to ai-slackbot-testing channel Perfect! I've successfully posted the message "Meeting in 5 minutes - from eval framework" to the ai-slackbot-testing channel. The message was posted with timestamp 1751349675.278699 and appears to have been sent from the Codex bot account. nan nan
# Add thumbsup to message 1751349675.278699 in ai-slackbot-testing channel Great! I've successfully added a thumbs up (__) reaction to the message with timestamp 1751349675.278699 in the ai-slackbot-testing channel. The reaction has been applied to the "Meeting in 5 minutes - from eval framework" message. It looks like someone has already reacted to this message with a thumbs up emoji as well! The Slack API returned an "already_reacted" error, which means either you or someone else has already added this reaction to the message.
#
# If you'd like to try a different reaction emoji, just let me know which one you'd prefer! nan
# Reply 'Will be there! from eval framework' to thread 1751349675.278699 in ai-slackbot-testing channel Perfect! I've successfully replied "Will be there!" to the thread with timestamp 1751349675.278699 in the ai-slackbot-testing channel. The reply was posted with timestamp 1751349872.760909 and is now part of that message thread. nan nan
# Show thread replies for 1751349675.278699  in ai-slackbot-testing Here are the thread replies for message 1751349675.278699 in the ai-slackbot-testing channel:
#
# Thread Messages
# Original Message (1751349675.278699)
#
# From: Codex bot
# Message: "Meeting in 5 minutes - from eval framework"
# Reactions: __ (1 reaction from the Codex bot itself)
# Reply 1 (1751349872.760909)
#
# From: Codex bot
# Message: "Will be there!"
# The thread contains the original meeting reminder message that we posted earlier, followed by the reply "Will be there!" that we just added. Both messages were posted by the Codex bot. The original message also has a thumbs up reaction that was added earlier. nan nan
# Get profile details for Mohitha Mohan Here are the profile details for Mohitha Mohan:
#
# Mohitha Mohan - Profile Details
# Basic Information:
#
# Full Name: Mohitha Mohan
# Username: mohitha_mohan
# User ID: U08FUTB4QLC
# Email: Mohitha@cxnpl.com
# Profile Details:
#
# Display Name: Mohitha Mohan
# First Name: Mohitha
# Last Name: Mohan
# Title: (No title set)
# Phone: (Not provided)
# Status: (No status message set)
# Profile Image:
# Has a custom profile image uploaded
# Avatar hash: fb39e0e7d7e7
# Various image sizes available (24x24 to 1024x1024 pixels)
# Other Details:
#
# No additional custom fields set up
# No Skype information provided
# Currently not in a huddle
# No status emoji or expiration set
# Mohitha appears to be a newer team member with a basic profile setup at Constantinople/CXNPL. nan nan
# Search for messages containing 'regex' from Oscar Fawkes I found 3 messages from Oscar Fawkes containing the word "regex". Here are the search results:
#
# Messages containing 'regex' from Oscar Fawkes
# 1. Digital Wallet HTML Terms/Conditions (August 19, 2024)
#
# Channel: squad-mese-coord
# Message: "Sharing the regex for Digital wallet HTML terms/conditions in case the proverbial bus beats me to writing it up formally - basically export html from word, open in vscode, find replace the below with empty string
# [;\s\n]color:[^']"
# Link: https://constantinoplehq.slack.com/archives/C056KSDAZPH/p1724033558168669?thread_ts=1724033558.168669
# 2. TXB Visa API Discussion (January 8, 2025)
#
# Channel: proj-txb-visa
# Message: "Their API is pretty expressive, if a message can't be processed you'll get 400 with field level explanation and regex if applicable"
# Link: https://constantinoplehq.slack.com/archives/C07SV2PD97X/p1741680690610569?thread_ts=1741677323.629989
# 3. Payee Name Validation (February 16, 2024)
#
# Channel: squad-mese-coord
# Message: "@Benjamin Staite @Peter Liang @Campbell Wang could you cross check the regex on the payee name FE and BE PRs for consistency? We'll need to test them together as well of course"
# Link: https://constantinoplehq.slack.com/archives/C056KSDAZPH/p1708039454108839?thread_ts=1708039454.108839
# The search found Oscar discussing regex patterns for HTML cleanup, API validation, and frontend/backend consistency checks for payee name validation. nan nan
# Search for food safari in sydney-office Great! I found 10 messages about "Food Safari" in the sydney-office channel. Here are the search results:
#
# Food Safari Messages in Sydney Office
# Recent Food Safari Events:
#
# 1. Latest - Sushi Jones (December 31, 2024)
#
# From: Ross Bevins Cameron
# Message: "Food Safari is here! Today we have a selection of different foods from Sushi Jones... Enjoy! __ ________"
# 2. Food Safari Despite Weather (December 31, 2024)
#
# From: Ross Bevins Cameron
# Message: "Despite the bad weather and PI Planning being moved, Food Safari is still going ahead today __"
# 3. Pablo's Kitchen (December 18, 2024)
#
# From: Ross Bevins Cameron
# Message: "Food Safari is here! This time we have ordered from Pablo's Kitchen... featuring fusions of foods & spices from ____ ____ ____ ____ Enjoy! ______"
# 4. Malacca Straits (June 4, 2024)
#
# From: Ross Bevins Cameron
# Message: "Food Safari is here! This week we have Malacca Straits on Broadway ______ Enjoy! __"
# 5. Grace of India (April 7, 2024)
#
# From: Ross Bevins Cameron
# Message: "The moment has come... Food Safari is here! __ Today we have Grace of India ____ __ come and get stuck in __"
# 6. Made in Italy (May 21, 2024)
#
# From: Ross Bevins Cameron
# Message: "Food Safari has arrived! This time we have... Made in Italy ________ Enjoy! __"
# 7. Italian Leftovers Reminder (May 22, 2024)
#
# From: Ross Bevins Cameron
# Message: "Just a reminder that we still have a lot of Food Safari left over, so no need to buy lunch today! ____ We'll also have plenty of fruit & avocados available to take home so please help yourselves ____"
# 8. Bavarian Buffet (May 21, 2024)
#
# From: Ross Bevins Cameron
# Message: "Food Safari is here! This week we have a Bavarian Buffet from Hut Dog Catering & Events. Enjoy! __________"
# Employee Responses:
#
# 9. Alan's Thanks (May 22, 2024)
#
# From: Alan Nguyen
# Message: "Thanks Ross! Nothing tastes better than saving money with food safari left overs __"
# 10. Irish Chinese Suggestion (February 12, 2024)
#
# From: Alan Nguyen
# Message: "We gotta get some Irish Chinese for food safari one day cc @Owen Hughes @Chloe Lee"
# The Food Safari appears to be a regular office lunch initiative organized by Ross Bevins Cameron, featuring different international cuisines for the Sydney office team to enjoy together! nan nan
# Get profile details for John Smith It looks like I couldn't find a user with that exact name. The search requires either an email address, username, account ID, or a more specific identifier.
#
# Could you provide:
#
# John Smith's email address (e.g., john.smith@company.com )
# Their username or account ID
# Or perhaps their display name is slightly different?
# This will help me retrieve their profile information accurately. nan nan
# Get me recent messages from the trump-supporters channel I searched through all the channels in your Slack workspace, and I couldn't find a channel named "trump-supporters". The channel list doesn't contain any channel with that name.
#
# The channels I found include various work-related channels like:
#
# general
# random
# tech-related channels
# project-specific channels
# team channels
# social channels (like pet-pics, foodlovers, games, etc.)
# Could you please:
#
# Double-check the channel name - it might be slightly different
# Verify that you have access to this channel
# Or let me know if you'd like messages from a different channel instead? nan nan
# Search for "petrichor" on slack The search for "petrichor" on Slack returned no results. There are currently no messages in your Slack workspace that contain the word "petrichor".
#
# This could mean:
#
# The term hasn't been mentioned in any messages
# It might be in channels you don't have access to
# It could be spelled differently or used in a different context
# Would you like me to try a different search term or help you with something else? nan nan

# %% [markdown]
# Running all prompts with the selected bedrock model (default: anthropic.claude-3-5-sonnet-20241022-v2:0)

# %%
results = []
iterations = 3
output_dir = 'output'

for i in range(iterations):
    for prompt, expected_response1, expected_response2, expected_response3 in prompt_expresponse_tuple:
        payload = {
            "model": model,
            "messages": [
                {"role": "user", "content": prompt}
            ],
            "tool_ids": ["server:0", "server:1"],
            "temperature": 0.7,
            "stream": False  # Set to True if you want to stream the response
        }
        print("Payload: ", payload)

        response = requests.post(
            f"{BASE_URL}/chat/completions", 
            json=payload,
            headers=headers
        )

        result = response.json()
        print("Result: ", result)
        if (result["choices"]):
            print("Result message: \n")
            print(result["choices"][0]["message"]["content"])
            row_result = {
                "prompt": prompt,
                "model": result["model"],
                "response": result["choices"][0]["message"]["content"],
                "expected_response_1": expected_response1,
                "expected_response_2": expected_response2,
                "expected_response_3": expected_response3,
                "usage_prompt_tokens": result["usage"]["prompt_tokens"],
                "usage_completion_tokens": result["usage"]["completion_tokens"],
                "usage_total_tokens": result["usage"]["total_tokens"]
            }
            results.append(row_result)
        else:
            continue

    results_df = pd.DataFrame(results)
    print(results_df)

    os.makedirs(output_dir, exist_ok=True)
    output_path = os.path.join(output_dir, 'chat_results_'+str(i+1)+'.csv')
    results_df.to_csv(output_path, index=False)
    print(f"Chat results no. {i+1}:----------------\n {results_df.head(3)}\nPut into output/chat_results_{i+1}.csv\n\n")
    # grid = DataGrid(results_df, selection_mode="row", layout={"height": "400px"})
    # display(grid)
# Out:
# Payload:  {'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'messages': [{'role': 'user', 'content': 'List all channels in the workspace'}], 'tool_ids': ['server:0', 'server:1'], 'temperature': 0.7, 'stream': False}
# Result:  {'id': 'chatcmpl-bcd3b430', 'created': 1751517395, 'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'length', 'logprobs': None, 'message': {'role': 'assistant', 'content': "I'll list all the channels in the workspace, organized by category to make it easier to navigate.\n\n# Slack Channels in the Workspace\n\n## Team & Squad Channels\n- #all-devs - All engineers of the company\n- #all-handsers\n- #backend-aws-resource-limit-alerts\n- #business-team - Discussion for business team\n- #client-solutions - Client solutions discussions\n- #client-success-team\n- #design - Design updates and feedback\n- #eng-backend - Engineering discussions for backend\n- #fe-gang - Frontend related issues\n- #finance - Finance workstream discussions\n- #frontend-gang - Frontend team channel\n- #guild-backend - Backend guild\n- #guild-devx - Developer experience guild\n- #guild-frontend - Frontend guild\n- #product - Product management team\n- #product-operations - Product operations\n- #security - Security questions and discussions\n- #squad-data - Data team requests\n- #squad-embedded - Embedded squad\n- #squad-lending - Lending squad\n- #squad-lending-team - Internal channel for lending team\n- #squad-lending-tech - Technical chat for lending squad\n- #squad-of-squads - On-pointers\n- #squad-onboarding-team - Onboarding squad\n- #squad-platform - Platform squad\n- #squad-prod-ops - Production operations squad\n- #squad-release - Release squad\n- #squad-txb - Transaction banking squad\n- #squad-ux - Webapp team\n- #team-squad-leads - Squad leads team\n\n## Project Channels\n- #proj-api-documentation - API documentation project\n- #proj-auth0 - Auth0 integration project\n- #proj-bank-feeds - Bank feeds project\n- #proj-bpay - BPAY integration\n- #proj-case-management - Case management project\n- #proj-cms - CMS project\n- #proj-dynamic-flows - Dynamic flows project\n- #proj-embedded - Embedded project\n- #proj-fincrime - Financial crime project\n- #proj-guided-activation - Guided activation project\n- #proj-intercom - Intercom integration\n- #proj-janus-mobile-app-2o - Mobile app 2.0 project\n- #proj-marketing - Marketing project\n- #proj-mobile-cicd-automation - Mobile CI/CD automation\n- #proj-multitenancy - Multi-tenancy project\n- #proj-nudges - Nudges project\n- #proj-observability - Observability project (Lumigo, Cloudwatch, K6)\n- #proj-ops-console-file-manager - Ops console file manager\n- #proj-ops-portal - Operations portal\n- #proj-payto - PayTo integration\n- #proj-pls-just-go-to-market - Go to market project\n- #proj-retail-ui - Retail UI project\n- #proj-term-deposits - Term deposits project\n- #proj-thesis - ESIPs Theses\n- #proj-tyro - Tyro integration\n- #proj-tyro-data - Tyro data project\n- #proj-tyro-mca - Tyro MCA project\n- #proj-tyro-onboarding - Tyro onboarding\n- #proj-tyro-platform-delivery - Tyro platform delivery\n- #proj-visual-regression - Visual regression testing\n\n## Help Channels\n- #help-engineering - Engineering queries\n- #help-force-merge - Help with force merges\n- #help-hr - HR related queries\n- #help-interviews-fe - Frontend interview help\n- #help-it - IT related queries\n- #help-legal-risk-compliance - Legal/risk/compliance queries\n- #help-lifts - Lift related help\n- #help-office-syd - Sydney office help\n- #help-third-party-vendors - Vendor management help\n\n## Product-Specific Channels\n- #banking-operations-products - Banking operations products\n- #digital-wallet - Google & Apple Pay\n- #digital-wallet-v2 - Digital wallet v2\n- #lending-bankers-console - Lending bankers console\n- #lending-collections - Lending collections\n- #lending-domain-model - Lending domain model\n- #lending-events - Lending events\n- #lending-hardships - Lending hardships\n- #lending-lifecycle - Lending lifecycle\n- #lending-lifecycle-bugs - Lending lifecycle bugs\n- #lending-lrc - Lending legal, risk, compliance\n- #lending-ops-ci - L ...
# Result message:
#
# I'll list all the channels in the workspace, organized by category to make it easier to navigate.
#
# # Slack Channels in the Workspace
#
# ## Team & Squad Channels
# - #all-devs - All engineers of the company
# - #all-handsers
# - #backend-aws-resource-limit-alerts
# - #business-team - Discussion for business team
# - #client-solutions - Client solutions discussions
# - #client-success-team
# - #design - Design updates and feedback
# - #eng-backend - Engineering discussions for backend
# - #fe-gang - Frontend related issues
# - #finance - Finance workstream discussions
# - #frontend-gang - Frontend team channel
# - #guild-backend - Backend guild
# - #guild-devx - Developer experience guild
# - #guild-frontend - Frontend guild
# - #product - Product management team
# - #product-operations - Product operations
# - #security - Security questions and discussions
# - #squad-data - Data team requests
# - #squad-embedded - Embedded squad
# - #squad-lending - Lending squad
# - #squad-lending-team - Internal channel for lending team
# - #squad-lending-tech - Technical chat for lending squad
# - #squad-of-squads - On-pointers
# - #squad-onboarding-team - Onboarding squad
# - #squad-platform - Platform squad
# - #squad-prod-ops - Production operations squad
# - #squad-release - Release squad
# - #squad-txb - Transaction banking squad
# - #squad-ux - Webapp team
# - #team-squad-leads - Squad leads team
#
# ## Project Channels
# - #proj-api-documentation - API documentation project
# - #proj-auth0 - Auth0 integration project
# - #proj-bank-feeds - Bank feeds project
# - #proj-bpay - BPAY integration
# - #proj-case-management - Case management project
# - #proj-cms - CMS project
# - #proj-dynamic-flows - Dynamic flows project
# - #proj-embedded - Embedded project
# - #proj-fincrime - Financial crime project
# - #proj-guided-activation - Guided activation project
# - #proj-intercom - Intercom integration
# - #proj-janus-mobile-app-2o - Mobile app 2.0 project
# - #proj-marketing - Marketing project
# - #proj-mobile-cicd-automation - Mobile CI/CD automation
# - #proj-multitenancy - Multi-tenancy project
# - #proj-nudges - Nudges project
# - #proj-observability - Observability project (Lumigo, Cloudwatch, K6)
# - #proj-ops-console-file-manager - Ops console file manager
# - #proj-ops-portal - Operations portal
# - #proj-payto - PayTo integration
# - #proj-pls-just-go-to-market - Go to market project
# - #proj-retail-ui - Retail UI project
# - #proj-term-deposits - Term deposits project
# - #proj-thesis - ESIPs Theses
# - #proj-tyro - Tyro integration
# - #proj-tyro-data - Tyro data project
# - #proj-tyro-mca - Tyro MCA project
# - #proj-tyro-onboarding - Tyro onboarding
# - #proj-tyro-platform-delivery - Tyro platform delivery
# - #proj-visual-regression - Visual regression testing
#
# ## Help Channels
# - #help-engineering - Engineering queries
# - #help-force-merge - Help with force merges
# - #help-hr - HR related queries
# - #help-interviews-fe - Frontend interview help
# - #help-it - IT related queries
# - #help-legal-risk-compliance - Legal/risk/compliance queries
# - #help-lifts - Lift related help
# - #help-office-syd - Sydney office help
# - #help-third-party-vendors - Vendor management help
#
# ## Product-Specific Channels
# - #banking-operations-products - Banking operations products
# - #digital-wallet - Google & Apple Pay
# - #digital-wallet-v2 - Digital wallet v2
# - #lending-bankers-console - Lending bankers console
# - #lending-collections - Lending collections
# - #lending-domain-model - Lending domain model
# - #lending-events - Lending events
# - #lending-hardships - Lending hardships
# - #lending-lifecycle - Lending lifecycle
# - #lending-lifecycle-bugs - Lending lifecycle bugs
# - #lending-lrc - Lending legal, risk, compliance
# - #lending-ops-ci - Lending operations CI
# - #lending-origination-bugs - Lending origination bugs
# - #lending-questions - Lending questions
# - #lending-serviceability - Lending serviceability
# - #loan-app-approval - Loan application approval
# - #merchant-stripe-tech - Merchant Stripe tech
# - #mortgages - Mortgages discussions
# - #openbanking - Open banking
# - #prod-cap-errors - Production CAP errors
# - #prod-card - Card-related activities in production
# - #prod-changelog-flags - Production changelog flags
# - #prod-collections-hardships - Production collections and hardships
# - #prod-lending - Production lending issues
# - #prod-management-console - Production management console
# - #prod-merchant - Production merchant
# - #prod-onboarding - Production onboarding
# - #prod-ops-onboarding - Production ops onboarding
# - #prod-platform-alerts - Production platform alerts
# - #prod-txb - Production TXB issues
# - #prod-webapp - Production webapp issues
# - #repayment-schedule-engine - Repayment schedule engine
# - #secured-term-loans - Secured term loans
# - #txb-merchant-acquiring - TXB merchant acquiring
# - #txb-merchant-product-design - TXB merchant product and design
# - #txb-proj-joint-accounts - TXB joint accounts project
# - #txb-proj-retail-accounts - TXB retail accounts project
# - #txb-proj-sweeps-savings - TXB sweeps savings project
# - #txb-proj-visa - TXB Visa project
#
# ## Social & Interest Groups
# - #anime-fans - Anime enthusiasts
# - #aquarist-enthusiasts - Fish enthusiasts
# - #ballers-of-lebronstantinople - Basketball chat
# - #boardgamers - Board game enthusiasts
# - #book-club - CXNPL Book Club
# - #chatter-cryptography - Cryptography discussions
# - #chatter-homelab - Home lab discussions
# - #chatter-mk - General chatter
# - #chatter-music - Music discussions
# - #city2surf - City2Surf run
# - #coffee-buddies - Coffee enthusiasts
# - #constanticycles - Cycling enthusiasts
# - #cricket-fans - Cricket discussions
# - #duolingo-amigos - Language learning motivation
# - #econ-book-club - Economics book club
# - #f1 - Formula 1 discussions
# - #foodlovers - Food discussions and recipes
# - #football-fans - Football discussions
# - #formula-1-club - Formula 1 club
# - #footy-chat - Australian football chat
# - #fossil-fellowship - Paleontology discussions
# - #gains-club - Gym and fitness
# - #good-reads - Blog post recommendations
# - #good-vibes-only - Positive vibes sharing
# - #idontcareiloveit - KFC enthusiasts
# - #letsgeteggy - Egg discussions
# - #memes - Meme appreciation
# - #movie-tv-club - Movies and TV discussions
# - #onlygamersallowed - Gaming discussions
# - #overheard - Overheard conversations
# - #pawn-stars - Chess enthusiasts
# - #pet-pics - Pet pictures
# - #points-hacks - Travel points and hacks
# - #rock-enthusiasts - Rock climbing
# - #run-club - Running enthusiasts
# - #shoutouts - Recognition and appreciation
# - #sparkle-buddies - Bubble enthusiasts
# - #stevie-fan-club - Stevie Wonder appreciation
# - #swim-club - Swimming enthusiasts
# - #sydney-jive-enthusiasts - Sydney jive dancing
# - #sydney-office - Sydney office discussions
# - #the-flop-house - CXNPL poker club
# - #the-green-room - Pipes discussions
# - #the-jam - Spotify music sharing
# - #travel - Travel discussions
# - #travel-recs - Travel recommendations
# - #weekly-trivia - Weekly trivia
#
# ## Operational Channels
# - #access_requests - Access change requests
# - #alerts-api-errors - API error alerts
# - #alerts-cicd - CICD issues alerts
# - #alerts-dev-gauth - Dev gauth alerts
# - #alerts-important-bugs
# Payload:  {'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'messages': [{'role': 'user', 'content': 'Show me all public channels'}], 'tool_ids': ['server:0', 'server:1'], 'temperature': 0.7, 'stream': False}
# Result:  {'id': 'chatcmpl-b6171605', 'created': 1751517415, 'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': 'I\'ve retrieved all public channels from the Slack workspace. There are over 400 channels covering various topics including team-specific channels, project channels, help channels, interest groups, and more. Here are some key categories:\n\n**Team/Squad Channels:**\n- #squad-users, #squad-lending, #squad-txb, #squad-platform, #squad-data, #squad-prod-ops, #squad-ux, #squad-cards\n- #fe-gang, #eng-backend, #all-devs, #guild-backend, #guild-frontend, #guild-devx\n\n**Project Channels:**\n- Many "proj-" prefixed channels like #proj-tyro, #proj-term-deposits, #proj-auth0\n- Specific initiatives like #proj-observability, #proj-api-documentation\n\n**Help Channels:**\n- #help-hr, #help-it, #help-engineering, #help-legal-risk-compliance, #help-office-syd\n- #help-bosphorus, #help-third-party-vendors\n\n**Product/Business Areas:**\n- #lending-lifecycle, #banking-operations-products, #product-operations\n- #vehicleloans, #digital-wallet, #mortgages, #collections\n\n**Production/Operations:**\n- #prod-lending, #prod-txb, #prod-webapp, #prod-merchant\n- #incident-response, #manual-changes, #change-review-board\n\n**Social/Interest Groups:**\n- #pet-pics, #foodlovers, #run-club, #pawn-stars (chess), #cricket-fans\n- #points-hacks, #movie-tv-club, #ballers-of-lebronstantinople (basketball)\n\n**General Communication:**\n- #general, #random\n- #announcements, #shoutouts\n\n**Technology-Specific:**\n- #cxnpl-aws, #temporal, #splunk, #security, #ai-cxnpl\n- #renovate-notifications-squad-platform\n\nWould you like me to provide more details about any specific category or channel?'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 47946, 'completion_tokens': 484, 'total_tokens': 48430}}
# Result message:
#
# I've retrieved all public channels from the Slack workspace. There are over 400 channels covering various topics including team-specific channels, project channels, help channels, interest groups, and more. Here are some key categories:
#
# **Team/Squad Channels:**
# - #squad-users, #squad-lending, #squad-txb, #squad-platform, #squad-data, #squad-prod-ops, #squad-ux, #squad-cards
# - #fe-gang, #eng-backend, #all-devs, #guild-backend, #guild-frontend, #guild-devx
#
# **Project Channels:**
# - Many "proj-" prefixed channels like #proj-tyro, #proj-term-deposits, #proj-auth0
# - Specific initiatives like #proj-observability, #proj-api-documentation
#
# **Help Channels:**
# - #help-hr, #help-it, #help-engineering, #help-legal-risk-compliance, #help-office-syd
# - #help-bosphorus, #help-third-party-vendors
#
# **Product/Business Areas:**
# - #lending-lifecycle, #banking-operations-products, #product-operations
# - #vehicleloans, #digital-wallet, #mortgages, #collections
#
# **Production/Operations:**
# - #prod-lending, #prod-txb, #prod-webapp, #prod-merchant
# - #incident-response, #manual-changes, #change-review-board
#
# **Social/Interest Groups:**
# - #pet-pics, #foodlovers, #run-club, #pawn-stars (chess), #cricket-fans
# - #points-hacks, #movie-tv-club, #ballers-of-lebronstantinople (basketball)
#
# **General Communication:**
# - #general, #random
# - #announcements, #shoutouts
#
# **Technology-Specific:**
# - #cxnpl-aws, #temporal, #splunk, #security, #ai-cxnpl
# - #renovate-notifications-squad-platform
#
# Would you like me to provide more details about any specific category or channel?
# Payload:  {'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'messages': [{'role': 'user', 'content': "Post 'Hello team! From eval framework here.' to channel C08UFS9HMCN"}], 'tool_ids': ['server:0', 'server:1'], 'temperature': 0.7, 'stream': False}
# Result:  {'id': 'chatcmpl-4d162379', 'created': 1751517422, 'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': 'I\'ve posted your message "Hello team! From eval framework here." to the channel successfully.'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 575, 'completion_tokens': 22, 'total_tokens': 597}}
# Result message:
#
# I've posted your message "Hello team! From eval framework here." to the channel successfully.
# Payload:  {'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'messages': [{'role': 'user', 'content': 'Add heart reaction to message at timestamp 1750300317.785949 in channel C08UFS9HMCN'}], 'tool_ids': ['server:0', 'server:1'], 'temperature': 0.7, 'stream': False}
# Result:  {'id': 'chatcmpl-76390d66', 'created': 1751517429, 'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': 'I tried to add a heart reaction to the message at timestamp 1750300317.785949 in channel C08UFS9HMCN, but I received an error indicating that the message already has a heart reaction from you. The error message specifically states "already_reacted", which means you\'ve previously added this same reaction to this message.'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 131, 'completion_tokens': 77, 'total_tokens': 208}}
# Result message:
#
# I tried to add a heart reaction to the message at timestamp 1750300317.785949 in channel C08UFS9HMCN, but I received an error indicating that the message already has a heart reaction from you. The error message specifically states "already_reacted", which means you've previously added this same reaction to this message.
# Payload:  {'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'messages': [{'role': 'user', 'content': "Reply to thread 1750300317.785949 in channel C08UFS9HMCN with 'Thanks for the update!'"}], 'tool_ids': ['server:0', 'server:1'], 'temperature': 0.7, 'stream': False}
# Result:  {'id': 'chatcmpl-fd22a1c7', 'created': 1751517436, 'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': 'I\'ve replied to the thread with "Thanks for the update!" in channel C08UFS9HMCN.'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 616, 'completion_tokens': 28, 'total_tokens': 644}}
# Result message:
#
# I've replied to the thread with "Thanks for the update!" in channel C08UFS9HMCN.
# Payload:  {'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'messages': [{'role': 'user', 'content': 'Get all replies from thread 1750300317.785949 in channel C08UFS9HMCN'}], 'tool_ids': ['server:0', 'server:1'], 'temperature': 0.7, 'stream': False}
# Result:  {'id': 'chatcmpl-d752f53a', 'created': 1751517449, 'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': '# Thread Replies for 1750300317.785949\n\n## Original Message:\n**Random Message Alert!** 🎲\nHey there! Did you know that octopuses have three hearts and blue blood? Pretty wild, right! 🐙💙\n*Just dropping some random facts while testing the AI chatbot functionality!*\nThis message was written by Codex on behalf of Alan Nguyen.\n\n## Replies:\n1. **User U08FUTB4QLC**: "Awesome, thats so cool!"\n\n2. **Codex (Bot)**: "Thanks for the update! This message was written by Codex on behalf of Mohitha Mohan."\n\n3. **Codex (Bot)**: "Thanks for the update!" (This message appears 15 times in the thread)\n\nThe original message received reactions including octopus (2), thumbs up (1), and heart (1).'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 8630, 'completion_tokens': 210, 'total_tokens': 8840}}
# Result message:
#
# # Thread Replies for 1750300317.785949
#
# ## Original Message:
# **Random Message Alert!** 🎲
# Hey there! Did you know that octopuses have three hearts and blue blood? Pretty wild, right! 🐙💙
# *Just dropping some random facts while testing the AI chatbot functionality!*
# This message was written by Codex on behalf of Alan Nguyen.
#
# ## Replies:
# 1. **User U08FUTB4QLC**: "Awesome, thats so cool!"
#
# 2. **Codex (Bot)**: "Thanks for the update! This message was written by Codex on behalf of Mohitha Mohan."
#
# 3. **Codex (Bot)**: "Thanks for the update!" (This message appears 15 times in the thread)
#
# The original message received reactions including octopus (2), thumbs up (1), and heart (1).
# Payload:  {'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'messages': [{'role': 'user', 'content': 'Show me all the users in the workspace'}], 'tool_ids': ['server:0', 'server:1'], 'temperature': 0.7, 'stream': False}
# Result:  {'id': 'chatcmpl-8d835399', 'created': 1751517505, 'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'length', 'logprobs': None, 'message': {'role': 'assistant', 'content': "# Slack Workspace Users\n\nHere's a list of all users in the workspace, organized alphabetically by username:\n\n| Username | Real Name | Title (if available) |\n|----------|-----------|----------------------|\n| aashita_trehan | Aashita Trehan | TW Developer |\n| adarsh_jegadeesan | Adarsh Jegadeesan | TW Developer |\n| aditya_jangid | Aditya Jangid | |\n| alan_nguyen | Alan Nguyen | Forward deployed prompt engineer |\n| alec_zhang | Alec Zhang | Where's the lamb sauce |\n| alex_fahmy | Alex Fahmy | |\n| alexandra_maher | Alexandra Maher | live laugh loan no longer |\n| andrew_chan | Andrew Chan | |\n| andy_truong | Andy Truong | Progamer |\n| aniket_chaudhary | Aniket Chaudhary | water connoisseur. i put H4O in my H20. and Seneór FE @txb |\n| ankit_chaudhary | Ankit Chaudhary | TXB |\n| anupam_nag | Anupam Nag | human |\n| arif_raja | Arif Raja | |\n| arthur_clement | Arthur Clement | |\n| arun_chakkaravarthi_m | Arun Chakkaravarthi M | Thoughtworks |\n| arun_manivannan | Arun Manivannan | master of awkward conversations |\n| ashok_murugesan | Ashok Murugesan | Release and Incindent Manager |\n| aswin_senniappan | Aswin Senniappan | |\n| athishaya_jain | Athishaya Jain | |\n| augufran | Augustin Francis | AWS TAM |\n| balvinder_s | Balvinder Balvinder | |\n| bella_langi | Bella Langi | |\n| ben_mcgrath | Ben McGrath | |\n| benjamin_staite | Benjamin Staite | Head of Basketball Operations |\n| bennett_chapman | Bennett Chapman | |\n| bhumanyu_kumar | Bhumanyu Kumar | TW Developer |\n| blake_belcastro | Blake Belcastro | Chief Widget Officer |\n| bradley_monks | Bradley Monks | |\n| brijesh_gajjar | Brijesh Gajjar | TW Developer |\n| bruce_nichols | Bruce Nichols | |\n| camilo_diaz | Camilo Diaz | TW Developer |\n| cameron_meindl | Cameron Meindl | Field CTO Constantinople |\n| campbell_wang | Campbell Wang | Emperor of Rome, Junior Software Engineer, 3x CCA Champion, Chicken Enthusiast, David Attenborough Impersonator, and Former Cult Leader |\n| carl_gibbs | Carl Gibbs | |\n| carolina_guedes | Carolina Guedes | |\n| chanura | Chanura Jayasinghe | |\n| chester_burns | Chester Burns | |\n| chloe_lee | Chloe Lee | |\n| christina_lee | Christina Lee | |\n| clare__kim | Clare Kim | |\n| daniel_son | Daniel Son | |\n| danielle_brockington | Danielle Brockington | |\n| darren_oakey | Darren Oakey | |\n| david_palmer | David Palmer | |\n| deepesh_moad | Deepesh Moad | |\n| defney_sneha_lobo | Defney Sneha Lobo | |\n| dhairya_punjabi | Dhairya Punjabi | Senior Software Developer |\n| di_challenor | Di Challenor | |\n| dino__antonelli | Dino Antonelli | |\n| divya_singapuri | Divya Singapuri | Financial Crime and Fraud Manager |\n| dominic_debono | Dominic Debono | Smartsheet Specialist |\n| duc_ahn_nguyen | Duc Ahn Nguyen | |\n| elisabeth_six | Elisabeth Six | |\n| elsa_hanson | Elsa Hanson | |\n| evan_kohilas | Evan Kohilas | Senior Software Engineer on the Platform Squad |\n| fahimabbas_hariyani | Fahimabbas Hariyani | |\n| faiz_waris | Faiz Waris | |\n| fatema_mandsourwala | Fatema Mandsourwala | |\n| felix_thummernicht | Felix Thummernicht | |\n| fergus_charles | Fergus Charles | In house chef 👨\u200d🍳 |\n| fullerlx | Lee Fuller | AWS |\n| gagan_chawara | Gagan Chawara | Backend Dev @ TXB |\n| galit_oran | Galit Oran | Client Delivery |\n| gautham_ontri | Gautham Ontri | Internet Mechanic |\n| glenn_adnum | Glenn Adnum | Collections and Hardship |\n| grace_gleeson | Grace Gleeson | CXNPL Botanist |\n| guru_ragothaman | Guru Ragothaman | Migration |\n| hamish_langford | Hamish Langford | |\n| hamish_rumbold | Hamish Rumbold | |\n| harshveer_kaur | Harshveer Kaur | Change is impossible in the fog of Ignorance : Itachi Uchiha |\n| hayley_rodgers | Hayley Rodgers | kitchen fai ...
# Result message:
#
# # Slack Workspace Users
#
# Here's a list of all users in the workspace, organized alphabetically by username:
#
# | Username | Real Name | Title (if available) |
# |----------|-----------|----------------------|
# | aashita_trehan | Aashita Trehan | TW Developer |
# | adarsh_jegadeesan | Adarsh Jegadeesan | TW Developer |
# | aditya_jangid | Aditya Jangid | |
# | alan_nguyen | Alan Nguyen | Forward deployed prompt engineer |
# | alec_zhang | Alec Zhang | Where's the lamb sauce |
# | alex_fahmy | Alex Fahmy | |
# | alexandra_maher | Alexandra Maher | live laugh loan no longer |
# | andrew_chan | Andrew Chan | |
# | andy_truong | Andy Truong | Progamer |
# | aniket_chaudhary | Aniket Chaudhary | water connoisseur. i put H4O in my H20. and Seneór FE @txb |
# | ankit_chaudhary | Ankit Chaudhary | TXB |
# | anupam_nag | Anupam Nag | human |
# | arif_raja | Arif Raja | |
# | arthur_clement | Arthur Clement | |
# | arun_chakkaravarthi_m | Arun Chakkaravarthi M | Thoughtworks |
# | arun_manivannan | Arun Manivannan | master of awkward conversations |
# | ashok_murugesan | Ashok Murugesan | Release and Incindent Manager |
# | aswin_senniappan | Aswin Senniappan | |
# | athishaya_jain | Athishaya Jain | |
# | augufran | Augustin Francis | AWS TAM |
# | balvinder_s | Balvinder Balvinder | |
# | bella_langi | Bella Langi | |
# | ben_mcgrath | Ben McGrath | |
# | benjamin_staite | Benjamin Staite | Head of Basketball Operations |
# | bennett_chapman | Bennett Chapman | |
# | bhumanyu_kumar | Bhumanyu Kumar | TW Developer |
# | blake_belcastro | Blake Belcastro | Chief Widget Officer |
# | bradley_monks | Bradley Monks | |
# | brijesh_gajjar | Brijesh Gajjar | TW Developer |
# | bruce_nichols | Bruce Nichols | |
# | camilo_diaz | Camilo Diaz | TW Developer |
# | cameron_meindl | Cameron Meindl | Field CTO Constantinople |
# | campbell_wang | Campbell Wang | Emperor of Rome, Junior Software Engineer, 3x CCA Champion, Chicken Enthusiast, David Attenborough Impersonator, and Former Cult Leader |
# | carl_gibbs | Carl Gibbs | |
# | carolina_guedes | Carolina Guedes | |
# | chanura | Chanura Jayasinghe | |
# | chester_burns | Chester Burns | |
# | chloe_lee | Chloe Lee | |
# | christina_lee | Christina Lee | |
# | clare__kim | Clare Kim | |
# | daniel_son | Daniel Son | |
# | danielle_brockington | Danielle Brockington | |
# | darren_oakey | Darren Oakey | |
# | david_palmer | David Palmer | |
# | deepesh_moad | Deepesh Moad | |
# | defney_sneha_lobo | Defney Sneha Lobo | |
# | dhairya_punjabi | Dhairya Punjabi | Senior Software Developer |
# | di_challenor | Di Challenor | |
# | dino__antonelli | Dino Antonelli | |
# | divya_singapuri | Divya Singapuri | Financial Crime and Fraud Manager |
# | dominic_debono | Dominic Debono | Smartsheet Specialist |
# | duc_ahn_nguyen | Duc Ahn Nguyen | |
# | elisabeth_six | Elisabeth Six | |
# | elsa_hanson | Elsa Hanson | |
# | evan_kohilas | Evan Kohilas | Senior Software Engineer on the Platform Squad |
# | fahimabbas_hariyani | Fahimabbas Hariyani | |
# | faiz_waris | Faiz Waris | |
# | fatema_mandsourwala | Fatema Mandsourwala | |
# | felix_thummernicht | Felix Thummernicht | |
# | fergus_charles | Fergus Charles | In house chef 👨‍🍳 |
# | fullerlx | Lee Fuller | AWS |
# | gagan_chawara | Gagan Chawara | Backend Dev @ TXB |
# | galit_oran | Galit Oran | Client Delivery |
# | gautham_ontri | Gautham Ontri | Internet Mechanic |
# | glenn_adnum | Glenn Adnum | Collections and Hardship |
# | grace_gleeson | Grace Gleeson | CXNPL Botanist |
# | guru_ragothaman | Guru Ragothaman | Migration |
# | hamish_langford | Hamish Langford | |
# | hamish_rumbold | Hamish Rumbold | |
# | harshveer_kaur | Harshveer Kaur | Change is impossible in the fog of Ignorance : Itachi Uchiha |
# | hayley_rodgers | Hayley Rodgers | kitchen fairy |
# | heather_prenter | Heather from Credit | Heather from Credit |
# | hrvoje_tutman | Hrvoje Tutman | |
# | hunter_fiddes | Hunter Fiddes | |
# | ido_zamir | Ido Zamir | Old Man with Soup |
# | ishaank_gupta | Ishaank Gupta | Senior FE @ Onboarding |
# | jake_marsden | Jake Marsden | |
# | james_cartledge | James Cartledge | |
# | jan-christian_basson | Jan-Christian Basson | |
# | jan_fok | Jan Fok | |
# | jasmine_chandran | Jasmine Chandran | |
# | jayant_khatkar | Jayant Khatkar | |
# | jed_nicholson | Jed Nicholson | |
# | jeff_zeng | Jeff Zeng | |
# | jeremy_smith | Jeremy Smith | Crab |
# | joe_little | Joseph Little | |
# | joel_mcintosh | Joel Mcintosh | |
# | jordan_yoong | Jordan Yoong | internet security guard |
# | joshua_valerie | Joshua Valerie | |
# | junaid_khan | Junaid Khan | Data Lead, Migrations |
# | jyotirmoy_roy | Jyotirmoy Roy | |
# | kaito_nakamichi | Kaito Nakamichi | average volatility enthusiast |
# | kanagadurga_subburaj | Kanagadurga Subburaj | Data Engineer |
# | katharina_jessica | Kathy | |
# | katherine_squire | Katherine Squire | |
# | keerthi_iyengar | Keerthi Iyengar | Chief Operating Officer |
# | keshav_goyal | Keshav Goyal | Software developer |
# | ketaki_thorat | Ketaki Thorat | |
# | komal | Komal Bansal | Dev@TXB |
# | krishna_atkuru | Krishna Atkuru | Interrupt-Driven Engineer |
# | kunal_sikri | Kunal Sikri | |
# | lachlan_mcgrath | Lachlan McGrath | Banh Mi Enthusiast |
# | laura_kim | Laura Kim | |
# | lawrence_shi | Lawrence Shi | i live for hardstyle baby |
# | liam_carruthers | Liam Carruthers | |
# | lily_doyle | Lily Doyle | |
# | liuxuefe | liuxuefe | |
# | lize__richard__lim | Lize (Richard) Lim | LiZard |
# | luke_mccartin | Luke McCartin | Thoughtworks |
# | luke_raven | Luke Raven | Head of FinCrime & Fraud |
# | macgregor_duncan | Macgregor
# Payload:  {'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'messages': [{'role': 'user', 'content': 'Get profile details for user U08FUTB4QLC'}], 'tool_ids': ['server:0', 'server:1'], 'temperature': 0.7, 'stream': False}
# Result:  {'id': 'chatcmpl-af2ad7d3', 'created': 1751517513, 'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': "# User Profile: Mohitha Mohan\n\n**Basic Information:**\n- **Full Name:** Mohitha Mohan\n- **Display Name:** Mohitha Mohan\n- **Email:** Mohitha@cxnpl.com\n- **User ID:** U08FUTB4QLC\n\n**Profile Details:**\n- No title specified\n- No phone number provided\n- No status message currently set\n- Has a custom profile picture\n\nThe profile appears to be active but doesn't contain additional information like job title, department, or other customized fields. The user has uploaded a custom profile image but hasn't set any current status."}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 736, 'completion_tokens': 142, 'total_tokens': 878}}
# Result message:
#
# # User Profile: Mohitha Mohan
#
# **Basic Information:**
# - **Full Name:** Mohitha Mohan
# - **Display Name:** Mohitha Mohan
# - **Email:** Mohitha@cxnpl.com
# - **User ID:** U08FUTB4QLC
#
# **Profile Details:**
# - No title specified
# - No phone number provided
# - No status message currently set
# - Has a custom profile picture
#
# The profile appears to be active but doesn't contain additional information like job title, department, or other customized fields. The user has uploaded a custom profile image but hasn't set any current status.
# Payload:  {'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'messages': [{'role': 'user', 'content': "Search for messages containing 'mcp server'"}], 'tool_ids': ['server:0', 'server:1'], 'temperature': 0.7, 'stream': False}
# Result:  {'id': 'chatcmpl-bc6f98b6', 'created': 1751517529, 'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': 'I searched for messages containing "mcp server" and found 10 results from Slack. Here\'s a summary of the key discussions:\n\n1. Team members are working on developing and implementing MCP (Multi-Call Protocol) servers for various tools:\n   - Slack integration\n   - Atlassian/Jira integration\n   - Microsoft 365 (emails, calendar, OneDrive)\n\n2. There have been some technical discussions about:\n   - Authentication flows for the MCP servers\n   - Bug fixes for empty string errors in the Atlassian MCP server\n   - Setting up mock servers in Docker containers\n   - Issues with health checks not passing\n\n3. Mohitha Mohan made improvements to the MCP server tool by:\n   - Returning only sections of metadata\n   - Increasing the default limit of channel items to 1000\n   - Testing the tool with Claude and Cursor\n\n4. Jeremy Smith requested approval for a Microsoft 365 MCP Server access request, mentioning that it uses device code flow for authentication.\n\n5. The AI team is working on releasing an internal AI chatbot with their own MCP servers, with a goal to create a systematic approach for adding new ones.\n\nWould you like me to dive deeper into any particular aspect of these discussions?'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 2600, 'completion_tokens': 283, 'total_tokens': 2883}}
# Result message:
#
# I searched for messages containing "mcp server" and found 10 results from Slack. Here's a summary of the key discussions:
#
# 1. Team members are working on developing and implementing MCP (Multi-Call Protocol) servers for various tools:
#    - Slack integration
#    - Atlassian/Jira integration
#    - Microsoft 365 (emails, calendar, OneDrive)
#
# 2. There have been some technical discussions about:
#    - Authentication flows for the MCP servers
#    - Bug fixes for empty string errors in the Atlassian MCP server
#    - Setting up mock servers in Docker containers
#    - Issues with health checks not passing
#
# 3. Mohitha Mohan made improvements to the MCP server tool by:
#    - Returning only sections of metadata
#    - Increasing the default limit of channel items to 1000
#    - Testing the tool with Claude and Cursor
#
# 4. Jeremy Smith requested approval for a Microsoft 365 MCP Server access request, mentioning that it uses device code flow for authentication.
#
# 5. The AI team is working on releasing an internal AI chatbot with their own MCP servers, with a goal to create a systematic approach for adding new ones.
#
# Would you like me to dive deeper into any particular aspect of these discussions?
# Payload:  {'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'messages': [{'role': 'user', 'content': 'Get recent messages from the ytg channel'}], 'tool_ids': ['server:0', 'server:1'], 'temperature': 0.7, 'stream': False}
# Result:  {'id': 'chatcmpl-653b0059', 'created': 1751517538, 'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': 'I apologize, but I couldn\'t retrieve messages from a channel called "ytg" because the channel was not found. This could be due to one of the following reasons:\n\n1. The channel name might be incorrect or misspelled\n2. The channel might be private and the API doesn\'t have access to it\n3. The channel might have been archived or deleted\n4. The channel might exist in a different workspace\n\nWould you like me to:\n- Try a different channel name?\n- List available channels that I can access?\n- Try another approach to find the information you\'re looking for?'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 86, 'completion_tokens': 130, 'total_tokens': 216}}
# Result message:
#
# I apologize, but I couldn't retrieve messages from a channel called "ytg" because the channel was not found. This could be due to one of the following reasons:
#
# 1. The channel name might be incorrect or misspelled
# 2. The channel might be private and the API doesn't have access to it
# 3. The channel might have been archived or deleted
# 4. The channel might exist in a different workspace
#
# Would you like me to:
# - Try a different channel name?
# - List available channels that I can access?
# - Try another approach to find the information you're looking for?
# Payload:  {'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'messages': [{'role': 'user', 'content': "Post 'Meeting in 5 minutes - from eval framework' to ai-slackbot-testing channel"}], 'tool_ids': ['server:0', 'server:1'], 'temperature': 0.7, 'stream': False}
# Result:  {'id': 'chatcmpl-e1bee990', 'created': 1751517545, 'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': 'I\'ve posted the message "Meeting in 5 minutes - from eval framework" to the ai-slackbot-testing channel successfully.'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 584, 'completion_tokens': 32, 'total_tokens': 616}}
# Result message:
#
# I've posted the message "Meeting in 5 minutes - from eval framework" to the ai-slackbot-testing channel successfully.
# Payload:  {'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'messages': [{'role': 'user', 'content': 'Add thumbsup to message 1751349675.278699 in ai-slackbot-testing channel'}], 'tool_ids': ['server:0', 'server:1'], 'temperature': 0.7, 'stream': False}
# Result:  {'id': 'chatcmpl-9ca86b52', 'created': 1751517553, 'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': 'I attempted to add a thumbsup reaction to the message with ID 1751349675.278699 in the ai-slackbot-testing channel, but I received an error indicating that the channel was not found. \n\nThis could be due to one of these reasons:\n1. The channel name "ai-slackbot-testing" might not exist\n2. I might not have access to that channel\n3. There might be a typo in the channel name\n\nWould you like me to try a different channel name, or would you like to verify the channel name and try again?'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 129, 'completion_tokens': 129, 'total_tokens': 258}}
# Result message:
#
# I attempted to add a thumbsup reaction to the message with ID 1751349675.278699 in the ai-slackbot-testing channel, but I received an error indicating that the channel was not found.
#
# This could be due to one of these reasons:
# 1. The channel name "ai-slackbot-testing" might not exist
# 2. I might not have access to that channel
# 3. There might be a typo in the channel name
#
# Would you like me to try a different channel name, or would you like to verify the channel name and try again?
# Payload:  {'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'messages': [{'role': 'user', 'content': "Reply 'Will be there! from eval framework' to thread 1751349675.278699 in ai-slackbot-testing channel"}], 'tool_ids': ['server:0', 'server:1'], 'temperature': 0.7, 'stream': False}
# Result:  {'id': 'chatcmpl-0044cce6', 'created': 1751517560, 'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': 'I\'ve replied to the thread in the ai-slackbot-testing channel with the message "Will be there! from eval framework".'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 620, 'completion_tokens': 31, 'total_tokens': 651}}
# Result message:
#
# I've replied to the thread in the ai-slackbot-testing channel with the message "Will be there! from eval framework".
# Payload:  {'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'messages': [{'role': 'user', 'content': 'Show thread replies for 1751349675.278699  in ai-slackbot-testing'}], 'tool_ids': ['server:0', 'server:1'], 'temperature': 0.7, 'stream': False}
# Result:  {'id': 'chatcmpl-f5567b2b', 'created': 1751517573, 'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': 'I apologize, but I wasn\'t able to retrieve the thread replies for the message ID you provided (1751349675.278699). The Slack API returned an error: "channel_not_found".\n\nThis could happen for a few reasons:\n- The message ID might be incorrect\n- The channel where this message exists might not be accessible to me\n- The thread might have been deleted\n\nTo successfully retrieve thread replies, I need:\n1. A valid message ID (timestamp)\n2. Access to the channel where the message exists\n\nIf you\'d like to try again, please confirm the message ID is correct and that it\'s in a channel I have access to. You can also provide the channel ID along with the message ID to help me locate it.'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 99, 'completion_tokens': 163, 'total_tokens': 262}}
# Result message:
#
# I apologize, but I wasn't able to retrieve the thread replies for the message ID you provided (1751349675.278699). The Slack API returned an error: "channel_not_found".
#
# This could happen for a few reasons:
# - The message ID might be incorrect
# - The channel where this message exists might not be accessible to me
# - The thread might have been deleted
#
# To successfully retrieve thread replies, I need:
# 1. A valid message ID (timestamp)
# 2. Access to the channel where the message exists
#
# If you'd like to try again, please confirm the message ID is correct and that it's in a channel I have access to. You can also provide the channel ID along with the message ID to help me locate it.
# Payload:  {'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'messages': [{'role': 'user', 'content': 'Get profile details for Mohitha Mohan'}], 'tool_ids': ['server:0', 'server:1'], 'temperature': 0.7, 'stream': False}
# Result:  {'id': 'chatcmpl-d997263c', 'created': 1751517586, 'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': '# Profile Details for Mohitha Mohan\n\n**Name:** Mohitha Mohan  \n**Email:** mohitha@cxnpl.com  \n**Avatar:** Available (48px version)\n\nThis user has a Jira account with the display name "Mohitha Mohan".'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 191, 'completion_tokens': 69, 'total_tokens': 260}}
# Result message:
#
# # Profile Details for Mohitha Mohan
#
# **Name:** Mohitha Mohan
# **Email:** mohitha@cxnpl.com
# **Avatar:** Available (48px version)
#
# This user has a Jira account with the display name "Mohitha Mohan".
# Payload:  {'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'messages': [{'role': 'user', 'content': "Search for messages containing 'regex' from Oscar Fawkes"}], 'tool_ids': ['server:0', 'server:1'], 'temperature': 0.7, 'stream': False}
# Result:  {'id': 'chatcmpl-99bc2b66', 'created': 1751517594, 'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': "I searched for messages containing the word 'regex' from Oscar Fawkes, but no results were found. It appears that Oscar Fawkes hasn't sent any messages containing the word 'regex' in the channels that are accessible to this search."}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 159, 'completion_tokens': 57, 'total_tokens': 216}}
# Result message:
#
# I searched for messages containing the word 'regex' from Oscar Fawkes, but no results were found. It appears that Oscar Fawkes hasn't sent any messages containing the word 'regex' in the channels that are accessible to this search.
# Payload:  {'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'messages': [{'role': 'user', 'content': 'Search for food safari in sydney-office'}], 'tool_ids': ['server:0', 'server:1'], 'temperature': 0.7, 'stream': False}
# Result:  {'id': 'chatcmpl-034bc269', 'created': 1751517610, 'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': 'I apologize, but I encountered an error when trying to search for "food safari in sydney-office" in Slack. The search functionality appears to be experiencing technical difficulties at the moment.\n\nHere are some alternatives you could try:\n1. Try the search again in a few minutes as it might be a temporary issue\n2. Use the Slack app directly to perform your search\n3. Try a more specific or different search term\n4. If you\'re looking for food options near the Sydney office, you might want to ask colleagues directly\n\nWould you like me to try a different approach to help you find information about food options near the Sydney office?'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 86, 'completion_tokens': 138, 'total_tokens': 224}}
# Result message:
#
# I apologize, but I encountered an error when trying to search for "food safari in sydney-office" in Slack. The search functionality appears to be experiencing technical difficulties at the moment.
#
# Here are some alternatives you could try:
# 1. Try the search again in a few minutes as it might be a temporary issue
# 2. Use the Slack app directly to perform your search
# 3. Try a more specific or different search term
# 4. If you're looking for food options near the Sydney office, you might want to ask colleagues directly
#
# Would you like me to try a different approach to help you find information about food options near the Sydney office?
# Payload:  {'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'messages': [{'role': 'user', 'content': 'Get profile details for John Smith'}], 'tool_ids': ['server:0', 'server:1'], 'temperature': 0.7, 'stream': False}
# Result:  {'id': 'chatcmpl-e6786cba', 'created': 1751517624, 'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': 'I couldn\'t find a profile for "John Smith" in Jira. The system couldn\'t determine how to look up this user. This could be because:\n\n1. The user doesn\'t exist in the Jira system\n2. You might need to provide a more specific identifier like a username or email address\n3. There might be multiple users with similar names\n\nWould you like to try searching with a different identifier, such as an email address or a specific username?'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 76, 'completion_tokens': 101, 'total_tokens': 177}}
# Result message:
#
# I couldn't find a profile for "John Smith" in Jira. The system couldn't determine how to look up this user. This could be because:
#
# 1. The user doesn't exist in the Jira system
# 2. You might need to provide a more specific identifier like a username or email address
# 3. There might be multiple users with similar names
#
# Would you like to try searching with a different identifier, such as an email address or a specific username?
# Payload:  {'model': 'apac.anthropic.claude-3-7-sonnet-20250219-v1:0', 'messages': [{'role': 'user', 'content': 'Get me recent messages from the trump-supporters channel'}], 'tool_ids': ['server:0', 'server:1'], 'temperature': 0.7, 'stream': False}
# ...
# 25  # Thread Replies for Message 1750300317.785949...
# 26  # Slack Workspace Users\n\nHere's a list of al...
# 27  # User Profile: Mohitha Mohan\n\n**Basic Infor...
# 28  I found 10 messages containing "mcp server" in...
# 29  I attempted to retrieve recent messages from a...
# 30  I've posted "Meeting in 5 minutes - from eval ...
# 31  I apologize, but I encountered an error when t...
# 32  I've replied to the thread in the ai-slackbot-...
# 33  I apologize, but I couldn't retrieve the threa...
# 34  # Mohitha Mohan's Profile\n\n**Name:** Mohitha...
# 35  I've searched for messages containing 'regex' ...
# 36  # Food Safari in Sydney Office\n\nBased on you...
# 37  I'm unable to retrieve profile details for "Jo...
# 38  I'm unable to retrieve messages from a "trump-...
# 39  I've searched for "petrichor" on Slack and fou...
# 40  I'll provide you with a list of all channels i...
# 41  I'll show you a list of all the public channel...
# 42  I've posted the message "Hello team! From eval...
# 43  I tried to add a heart reaction to the message...
# 44  I apologize for the error when trying to reply...
# 45  # Thread Replies from 1750300317.785949\n\nI'v...
# 46  # Slack Workspace Users\n\nHere's a list of al...
# 47  # User Profile: Mohitha Mohan\n\nHere are the ...
# 48  I searched for messages containing "mcp server...
# 49  I wasn't able to retrieve messages from a chan...
# 50  I've posted the message "Meeting in 5 minutes ...
# 51  I wasn't able to add a thumbsup reaction to th...
# 52  I've replied to the thread in the ai-slackbot-...
# 53  I'm sorry, but I couldn't retrieve the thread ...
# 54  # Mohitha Mohan's Profile\n\n**Name:** Mohitha...
# 55  I've searched for messages containing 'regex' ...
# 56  # Food Safari in Sydney Office\n\nBased on the...
# 57  I couldn't find a Jira profile for "John Smith...
# 58  I don't see any channel named "trump-supporter...
# 59  I searched for "petrichor" on Slack and found ...
#
#                                   expected_response_1  \
# 0   Here are all the channels in the Slack workspa...
# 1   Here are all the public channels available in ...
# 2   I successfully posted the message \Hello team!...
# 3   Great! I've successfully added a heart reactio...
# 4   Perfect! I've successfully replied to the thre...
# 5   Here are all the replies in the thread startin...
# 6   Here are all the users in your Slack workspace...
# 7   Here are the detailed profile information for ...
# 8   Here are the search results for messages conta...
# 9   I've successfully retrieved the recent message...
# 10  Perfect! I've successfully posted the message ...
# 11  Great! I've successfully added a thumbs up (__...
# 12  Perfect! I've successfully replied "Will be th...
# 13  Here are the thread replies for message 175134...
# 14  Here are the profile details for Mohitha Mohan...
# 15  I found 3 messages from Oscar Fawkes containin...
# 16  Great! I found 10 messages about "Food Safari"...
# 17  It looks like I couldn't find a user with that...
# 18  I searched through all the channels in your Sl...
# 19  The search for "petrichor" on Slack returned n...
# 20  Here are all the channels in the Slack workspa...
# 21  Here are all the public channels available in ...
# 22  I successfully posted the message \Hello team!...
# 23  Great! I've successfully added a heart reactio...
# 24  Perfect! I've successfully replied to the thre...
# 25  Here are all the replies in the thread startin...
# 26  Here are all the users in your Slack workspace...
# 27  Here are the detailed profile information for ...
# 28  Here are the search results for messages conta...
# 29  I've successfully retrieved the recent message...
# 30  Perfect! I've successfully posted the message ...
# 31  Great! I've successfully added a thumbs up (__...
# 32  Perfect! I've successfully replied "Will be th...
# 33  Here are the thread replies for message 175134...
# 34  Here are the profile details for Mohitha Mohan...
# 35  I found 3 messages from Oscar Fawkes containin...
# 36  Great! I found 10 messages about "Food Safari"...
# 37  It looks like I couldn't find a user with that...
# 38  I searched through all the channels in your Sl...
# 39  The search for "petrichor" on Slack returned n...
# 40  Here are all the channels in the Slack workspa...
# 41  Here are all the public channels available in ...
# 42  I successfully posted the message \Hello team!...
# 43  Great! I've successfully added a heart reactio...
# 44  Perfect! I've successfully replied to the thre...
# 45  Here are all the replies in the thread startin...
# 46  Here are all the users in your Slack workspace...
# 47  Here are the detailed profile information for ...
# 48  Here are the search results for messages conta...
# 49  I've successfully retrieved the recent message...
# 50  Perfect! I've successfully posted the message ...
# 51  Great! I've successfully added a thumbs up (__...
# 52  Perfect! I've successfully replied "Will be th...
# 53  Here are the thread replies for message 175134...
# 54  Here are the profile details for Mohitha Mohan...
# 55  I found 3 messages from Oscar Fawkes containin...
# 56  Great! I found 10 messages about "Food Safari"...
# 57  It looks like I couldn't find a user with that...
# 58  I searched through all the channels in your Sl...
# 59  The search for "petrichor" on Slack returned n...
#
#                                   expected_response_2  expected_response_3  \
# 0                                                 NaN                  NaN
# 1                                                 NaN                  NaN
# 2                                                 NaN                  NaN
# 3   It looks like a heart reaction has already bee...                  NaN
# 4                                                 NaN                  NaN
# 5                                                 NaN                  NaN
# 6                                                 NaN                  NaN
# 7                                                 NaN                  NaN
# 8                                                 NaN                  NaN
# 9                                                 NaN                  NaN
# 10                                                NaN                  NaN
# 11  It looks like someone has already reacted to t...                  NaN
# 12                                                NaN                  NaN
# 13                                                NaN                  NaN
# 14                                                NaN                  NaN
# 15                                                NaN                  NaN
# 16                                                NaN                  NaN
# 17                                                NaN                  NaN
# 18                                                NaN                  NaN
# 19                                                NaN                  NaN
# 20                                                NaN                  NaN
# 21                                                NaN                  NaN
# 22                                                NaN                  NaN
# 23  It looks like a heart reaction has already bee...                  NaN
# 24                                                NaN                  NaN
# 25                                                NaN                  NaN
# 26                                                NaN                  NaN
# 27                                                NaN                  NaN
# 28                                                NaN                  NaN
# 29                                                NaN                  NaN
# 30                                                NaN                  NaN
# 31  It looks like someone has already reacted to t...                  NaN
# 32                                                NaN                  NaN
# 33                                                NaN                  NaN
# 34                                                NaN                  NaN
# 35                                                NaN                  NaN
# 36                                                NaN                  NaN
# 37                                                NaN                  NaN
# 38                                                NaN                  NaN
# 39                                                NaN                  NaN
# 40                                                NaN                  NaN
# 41                                                NaN                  NaN
# 42                                                NaN                  NaN
# 43  It looks like a heart reaction has already bee...                  NaN
# 44                                                NaN                  NaN
# 45                                                NaN                  NaN
# 46                                                NaN                  NaN
# 47                                                NaN                  NaN
# 48                                                NaN                  NaN
# 49                                                NaN                  NaN
# 50                                                NaN                  NaN
# 51  It looks like someone has already reacted to t...                  NaN
# 52                                                NaN                  NaN
# 53                                                NaN                  NaN
# 54                                                NaN                  NaN
# 55                                                NaN                  NaN
# 56                                                NaN                  NaN
# 57                                                NaN                  NaN
# 58                                                NaN                  NaN
# 59                                                NaN                  NaN
#
#     usage_prompt_tokens  usage_completion_tokens  usage_total_tokens
# 0                 47947                     2048               49995
# 1                 47946                      484               48430
# 2                   575                       22                 597
# 3                   131                       77                 208
# 4                   616                       28                 644
# 5                  8630                      210                8840
# 6                 11014                     2048               13062
# 7                   736                      142                 878
# 8                  2600                      283                2883
# 9                    86                      130                 216
# 10                  584                       32                 616
# 11                  129                      129                 258
# 12                  620                       31                 651
# 13                   99                      163                 262
# 14                  191                       69                 260
# 15                  159                       57                 216
# 16                   86                      138                 224
# 17                   76                      101                 177
# 18                   88                      104                 192
# 19                  149                       40                 189
# 20                47947                      405               48352
# 21                47946                      310               48256
# 22                  576                       38                 614
# 23                  131                       80                 211
# 24                  615                       27                 642
# 25                 9083                      261                9344
# 26                11014                     2048               13062
# 27                  736                      146                 882
# 28                 2600                      343                2943
# 29                   86                      126                 212
# 30                  581                       29                 610
# 31                  129                      119                 248
# 32                  622                       31                 653
# 33                   99                      129                 228
# 34                  191                       68                 259
# 35                  159                       54                 213
# 36                 1985                      254                2239
# 37                   76                      139                 215
# 38                   88                      143                 231
# 39                  149                       35                 184
# 40                47947                     1144               49091
# 41                47946                      819               48765
# 42                  577                       31                 608
# 43                  131                       79                 210
# 44                  113                       59                 172
# 45                 9085                      203                9288
# 46                11014                     2048               13062
# 47                  736                      144                 880
# 48                 2600                      305                2905
# 49                   86                      133                 219
# 50                  584                       31                 615
# 51                  129                      131                 260
# 52                  622                       31                 653
# 53                   99                      165                 264
# 54                  191                       70                 261
# 55                  159                       59                 218
# 56                 1983                      331                2314
# 57                   76                       87                 163
# 58                   88                       93                 181
# 59                  149                       36                 185
# Chat results no. 3:----------------
#                                                prompt  \
# 0                 List all channels in the workspace
# 1                        Show me all public channels
# 2  Post 'Hello team! From eval framework here.' t...
#
#                                             model  \
# 0  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 1  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 2  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
#
#                                             response  \
# 0  I'll list all the channels in the workspace, o...
# 1  I've retrieved all public channels from the Sl...
# 2  I've posted your message "Hello team! From eva...
#
#                                  expected_response_1 expected_response_2  \
# 0  Here are all the channels in the Slack workspa...                 NaN
# 1  Here are all the public channels available in ...                 NaN
# 2  I successfully posted the message \Hello team!...                 NaN
#
#    expected_response_3  usage_prompt_tokens  usage_completion_tokens  \
# 0                  NaN                47947                     2048
# 1                  NaN                47946                      484
# 2                  NaN                  575                       22
#
#    usage_total_tokens
# 0               49995
# 1               48430
# 2                 597
# Put into output/chat_results_3.csv

# %% [markdown]
# # Evaluating the Responses

# %% [markdown]
# ## Selecting evaluation model

# %%
model_eval = "apac.anthropic.claude-sonnet-4-20250514-v1:0"
print("You selected:", model_eval)
# Out:
# You selected: apac.anthropic.claude-sonnet-4-20250514-v1:0

# %%
# importlib.reload(eval_prompt) 
print(eval_prompt.evaluation_prompt)
# Out:
# You are an expert evaluator tasked with assessing how well an LLM response matches one of several expected correct responses.
#
# **EVALUATION DATA:**
# [BEGIN DATA]
# [Prompt]: {prompt}
# [LLM Response]: {response}
# [Expected Response 1]: {expected_response_1}
# [Expected Response 2]: {expected_response_2}
# [Expected Response 3]: {expected_response_3}
# [END DATA]
#
# **EVALUATION CRITERIA:**
# You must determine which ONE expected response the LLM response most closely matches, then score the quality of that match using this 5-point rubric:
#
# • **Score 5 (Excellent Match):** The response conveys the same core meaning as the selected expected response, even if worded differently
# • **Score 4 (Good Match):** The response matches the selected expected response with only minor differences (e.g., slight wording variations, additional context that doesn't change the meaning)
# • **Score 3 (Partial Match):** The response partially matches the selected expected response but has significant differences that affect clarity or completeness
# • **Score 2 (Poor Match):** The response shows some relation to the selected expected response but fails to convey the correct meaning or contains substantial errors
# • **Score 1 (No Match):** The response does not meaningfully match the selected expected response in meaning, content, or intent
#
# **EVALUATION STEPS:**
# 1. **Identify Best Match:** Compare the LLM response to each expected response and identify which ONE expected response it most closely resembles in meaning and content
# 2. **Score the Match:** Using only the selected expected response as your reference, apply the scoring rubric to rate how well the LLM response matches that specific expected response
# 3. **Binary Decision:** Determine if the response acceptably matches the selected expected response (scores 3-5 = "yes", scores 1-2 = "no")
#
# **IMPORTANT NOTES:**
# - Focus on semantic meaning, not exact wording
# - You must select only ONE expected response as your comparison baseline
# - Score based solely on how well the LLM response matches your selected expected response
# - Consider context and intent, not just literal text matching
# - Minor stylistic differences should not significantly impact scoring
# - If uncertain between two scores, choose the higher score
#
# **REQUIRED OUTPUT FORMAT:**
# Return your evaluation as a JSON object with EXACTLY the below structure, with no preceeding or trailing characters and no additional text.
# {{
#     "selected_expected_response": "<copy of the expected response you identified as most similar>",
#     "score": <integer 1-5>,
#     "answer": "<yes or no>",
#     "reasoning": "<2-3 sentence explanation comparing the LLM response to your selected expected response and justifying your score>"
# }}
#
# Begin your evaluation now.

# %% [markdown]
# ## Getting all prompts, responses and expected responses.

# %%
output_dir = 'eval_output'

# Get a list of all chat_results_*.csv files
files = glob.glob('output/chat_results_*.csv')
eval_iterations = len(files)
print(f"Found {eval_iterations} chat results files")
# Out:
# Found 3 chat results files

# %%
print(eval_prompt.evaluation_prompt)
# Out:
# You are an expert evaluator assessing how well an LLM response matches expected responses.
#
# **EVALUATION DATA:**
# [BEGIN DATA]
# [Prompt]: {prompt}
# [LLM Response]: {response}
# [Expected Response 1]: {expected_response_1}
# [Expected Response 2]: {expected_response_2}
# [Expected Response 3]: {expected_response_3}
# [END DATA]
#
# **TASK:**
# 1. Compare the LLM response to each expected response and identify which ONE it most closely matches
# 2. Score the match quality using this 5-point scale:
#    - **5 (Excellent):** Same core meaning, even if worded differently
#    - **4 (Good):** Minor differences only (slight wording variations)
#    - **3 (Partial):** Significant differences affecting clarity/completeness
#    - **2 (Poor):** Some relation but fails to convey correct meaning
#    - **1 (No Match):** No meaningful match in meaning/content/intent
# 3. Determine acceptance: scores 3-5 = "yes", scores 1-2 = "no"
#
# **CRITICAL OUTPUT REQUIREMENTS:**
# - You MUST return ONLY a JSON object with EXACTLY these 4 fields
# - Use EXACTLY these field names (case-sensitive): "selected_expected_response", "score", "answer", "reasoning"
# - DO NOT add any other fields or modify field names
# - DO NOT include any text before or after the JSON
# - DO NOT include markdown code blocks or formatting
# - DO NOT include a comma after the last field in the JSON object.
# - The value of the "reasoning" field should be a string, with no extra characters (such as commas, periods, or whitespace) after the closing quotation mark.
#
# **REQUIRED JSON FORMAT:**
# {{
#     "selected_expected_response": "<exact copy of the expected response you selected>",
#     "score": <integer from 1 to 5>,
#     "answer": "<exactly 'yes' or 'no' in lowercase>",
#     "reasoning": "<2-3 sentence explanation comparing LLM response to selected expected response>"
# }}
#
# Focus on semantic meaning over exact wording. When uncertain between scores, choose the lower score.
#
# Return only the JSON object now:

# %%
for i in range(eval_iterations):
    all_eval_results = []

    try:
        data = pd.read_csv('output/chat_results_'+str(i+1)+'.csv')
        prompts_expected_responses = data[['prompt','response', 'expected_response_1', 'expected_response_2', 'expected_response_3']].values.tolist()
    except FileNotFoundError:
        print(f"Error: output/chat_results_{i+1}.csv not found.")
        break

    print(f"Chat results no. {i+1}:----------------\n {prompts_expected_responses}\n")

    for prompt, response, expected_response1, expected_response2, expected_response3 in prompts_expected_responses:
        # print(comparision_eval_prompt)
        inuse_eval_prompt = eval_prompt.evaluation_prompt.format(prompt=prompt, response=response, expected_response_1=expected_response1, expected_response_2=expected_response2, expected_response_3=expected_response3)
        # print(inuse_eval_prompt)

        payload = {
            "model": model_eval,
            "messages": [
                {"role": "user", "content": inuse_eval_prompt}
            ],
            "temperature": 0.7,
            "stream": False  # Set to True if you want to stream the response
        }

        result = requests.post(
            f"{BASE_URL}/chat/completions",
            json=payload,
            headers=headers
        ).json()
        # print(f"Evaluation results for prompt {prompt}: {result}")

        print(result)

        if result:
            if result["choices"]:
                eval_result = result["choices"][0]["message"]["content"]
                print(eval_result)
                eval_result_json = json.loads(eval_result)
                print(f"Evaluation results for prompt {prompt}: \n")
                print(eval_result_json)

                row_result = {
                    "prompt": prompt,
                    "model": result["model"],
                    "response": response,
                    "selected_expected_response": eval_result_json["selected_expected_response"],
                    "score": eval_result_json["score"],
                    "answer": eval_result_json["answer"],
                    "reasoning": eval_result_json["reasoning"]
                }
                all_eval_results.append(row_result)
            else:
                continue
        else:
            continue

    all_eval_results_df = pd.DataFrame(all_eval_results)
    # print(all_eval_results_df)

    os.makedirs(output_dir, exist_ok=True)
    output_path = os.path.join(output_dir, 'eval_results_'+str(i+1)+'.csv')
    all_eval_results_df.to_csv(output_path, index=False)
    print(f"Evaluation results for chat results no. {i+1}:----------------\n {all_eval_results_df.head(3)}\nSaved to {output_path}\n\n")
# Out:
# Chat results no. 1:----------------
#  [['List all channels in the workspace', "I'll list all the channels in the workspace, organized by category to make it easier to navigate.\n\n# Slack Channels in the Workspace\n\n## Team & Squad Channels\n- #all-devs - All engineers of the company\n- #all-handsers\n- #backend-aws-resource-limit-alerts\n- #business-team - Discussion for business team\n- #client-solutions - Client solutions discussions\n- #client-success-team\n- #design - Design updates and feedback\n- #eng-backend - Engineering discussions for backend\n- #fe-gang - Frontend related issues\n- #finance - Finance workstream discussions\n- #frontend-gang - Frontend team channel\n- #guild-backend - Backend guild\n- #guild-devx - Developer experience guild\n- #guild-frontend - Frontend guild\n- #product - Product management team\n- #product-operations - Product operations\n- #security - Security questions and discussions\n- #squad-data - Data team requests\n- #squad-embedded - Embedded squad\n- #squad-lending - Lending squad\n- #squad-lending-team - Internal channel for lending team\n- #squad-lending-tech - Technical chat for lending squad\n- #squad-of-squads - On-pointers\n- #squad-onboarding-team - Onboarding squad\n- #squad-platform - Platform squad\n- #squad-prod-ops - Production operations squad\n- #squad-release - Release squad\n- #squad-txb - Transaction banking squad\n- #squad-ux - Webapp team\n- #team-squad-leads - Squad leads team\n\n## Project Channels\n- #proj-api-documentation - API documentation project\n- #proj-auth0 - Auth0 integration project\n- #proj-bank-feeds - Bank feeds project\n- #proj-bpay - BPAY integration\n- #proj-case-management - Case management project\n- #proj-cms - CMS project\n- #proj-dynamic-flows - Dynamic flows project\n- #proj-embedded - Embedded project\n- #proj-fincrime - Financial crime project\n- #proj-guided-activation - Guided activation project\n- #proj-intercom - Intercom integration\n- #proj-janus-mobile-app-2o - Mobile app 2.0 project\n- #proj-marketing - Marketing project\n- #proj-mobile-cicd-automation - Mobile CI/CD automation\n- #proj-multitenancy - Multi-tenancy project\n- #proj-nudges - Nudges project\n- #proj-observability - Observability project (Lumigo, Cloudwatch, K6)\n- #proj-ops-console-file-manager - Ops console file manager\n- #proj-ops-portal - Operations portal\n- #proj-payto - PayTo integration\n- #proj-pls-just-go-to-market - Go to market project\n- #proj-retail-ui - Retail UI project\n- #proj-term-deposits - Term deposits project\n- #proj-thesis - ESIPs Theses\n- #proj-tyro - Tyro integration\n- #proj-tyro-data - Tyro data project\n- #proj-tyro-mca - Tyro MCA project\n- #proj-tyro-onboarding - Tyro onboarding\n- #proj-tyro-platform-delivery - Tyro platform delivery\n- #proj-visual-regression - Visual regression testing\n\n## Help Channels\n- #help-engineering - Engineering queries\n- #help-force-merge - Help with force merges\n- #help-hr - HR related queries\n- #help-interviews-fe - Frontend interview help\n- #help-it - IT related queries\n- #help-legal-risk-compliance - Legal/risk/compliance queries\n- #help-lifts - Lift related help\n- #help-office-syd - Sydney office help\n- #help-third-party-vendors - Vendor management help\n\n## Product-Specific Channels\n- #banking-operations-products - Banking operations products\n- #digital-wallet - Google & Apple Pay\n- #digital-wallet-v2 - Digital wallet v2\n- #lending-bankers-console - Lending bankers console\n- #lending-collections - Lending collections\n- #lending-domain-model - Lending domain model\n- #lending-events - Lending events\n- #lending-hardships - Lending hardships\n- #lending-lifecycle - Lending lifecycle\n- #lending-lifecycle-bugs - Lending lifecycle bugs\n- #lending-lrc - Lending legal, risk, compliance\n- #lending-ops-ci - Lending operations CI\n- #lending-origination-bugs - Lending origination bugs\n- #lending-questions - Lending questions\n- #lending-serviceability - Lending serviceability\n- #loan-app-approval - Loan application approval ...
#
# {'id': 'chatcmpl-7b077354', 'created': 1751521031, 'model': 'apac.anthropic.claude-sonnet-4-20250514-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': '{\n    "selected_expected_response": "Here are all the channels in the Slack workspace:\\n\\nMain Company Channels:\\n#general (201 members) - Main company-wide channel for announcements and team conversations\\n#random (199 members) - Casual conversation and team jokes\\n#help-it (196 members) - IT related queries\\n#help-hr (191 members) - HR related queries\\n#help-legal-risk-compliance (97 members) - Legal/risk/compliance queries\\nEngineering & Tech Channels:\\n#all-devs (132 members) - All engineers company-wide\\n#plz-review (109 members) - Code review requests\\n#eng-backend (102 members) - Backend engineering discussions\\n#fe-gang (89 members) - Frontend engineering team\\n#guild-backend (33 members) - Backend guild\\n#guild-devx (132 members) - Developer experience guild\\nProduct & Operations:\\n#product (76 members) - Product management discussions\\n#operations-service-model (4 members) - Operations organization\\n#prod-onboarding (69 members) - Production onboarding\\n#incident-response (97 members) - Incident response FAQ\\nBusiness & Finance:\\n#finance (37 members) - Finance workstream\\n#business-team (4 members) - Business team discussions\\n#intel (96 members) - Competitor and client intelligence\\n#client-implementation-and-governance (3 members) - Client work\\nTeam Squads:\\n#squad-users (102 members) - User-focused squad\\n#squad-lending (95 members) - Lending team\\n#squad-mese (21 members) - Payments, Payees, Cards squad\\n#squad-platform (106 members) - Platform squad\\n#squad-data (98 members) - Data team\\nSocial & Fun:\\n#pet-pics (51 members) - Pet photos\\n#foodlovers (44 members) - Food discussions\\n#good-reads (41 members) - Blog post recommendations\\n#run-club (41 members) - Running club\\n#gains-club (20 members) - Gym and fitness\\n#coffee-buddies (49 members) - Coffee meetups\\nOffice Locations:\\n#sydney-office (101 members) - Sydney office coordination\\n#melbourne-office (8 members) - Melbourne office\\n#india-office (58 members) - India office\\nThe workspace has a total of 580+ channels covering everything from technical projects and production alerts to social clubs and office coordination. The channels are well-organized with clear naming conventions (prefixes like proj-, squad-, help-, vendor-, etc.) to help users find relevant discussions.",\n    "score": 3,\n    "answer": "yes",\n    "reasoning": "Both responses list Slack channels organized by categories, but they contain significantly different channel sets with some overlap. The LLM response includes many more channels (200+) while the expected response has fewer channels but includes member counts and different organizational structure."\n}'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 3150, 'completion_tokens': 724, 'total_tokens': 3874}}
# {
#     "selected_expected_response": "Here are all the channels in the Slack workspace:\n\nMain Company Channels:\n#general (201 members) - Main company-wide channel for announcements and team conversations\n#random (199 members) - Casual conversation and team jokes\n#help-it (196 members) - IT related queries\n#help-hr (191 members) - HR related queries\n#help-legal-risk-compliance (97 members) - Legal/risk/compliance queries\nEngineering & Tech Channels:\n#all-devs (132 members) - All engineers company-wide\n#plz-review (109 members) - Code review requests\n#eng-backend (102 members) - Backend engineering discussions\n#fe-gang (89 members) - Frontend engineering team\n#guild-backend (33 members) - Backend guild\n#guild-devx (132 members) - Developer experience guild\nProduct & Operations:\n#product (76 members) - Product management discussions\n#operations-service-model (4 members) - Operations organization\n#prod-onboarding (69 members) - Production onboarding\n#incident-response (97 members) - Incident response FAQ\nBusiness & Finance:\n#finance (37 members) - Finance workstream\n#business-team (4 members) - Business team discussions\n#intel (96 members) - Competitor and client intelligence\n#client-implementation-and-governance (3 members) - Client work\nTeam Squads:\n#squad-users (102 members) - User-focused squad\n#squad-lending (95 members) - Lending team\n#squad-mese (21 members) - Payments, Payees, Cards squad\n#squad-platform (106 members) - Platform squad\n#squad-data (98 members) - Data team\nSocial & Fun:\n#pet-pics (51 members) - Pet photos\n#foodlovers (44 members) - Food discussions\n#good-reads (41 members) - Blog post recommendations\n#run-club (41 members) - Running club\n#gains-club (20 members) - Gym and fitness\n#coffee-buddies (49 members) - Coffee meetups\nOffice Locations:\n#sydney-office (101 members) - Sydney office coordination\n#melbourne-office (8 members) - Melbourne office\n#india-office (58 members) - India office\nThe workspace has a total of 580+ channels covering everything from technical projects and production alerts to social clubs and office coordination. The channels are well-organized with clear naming conventions (prefixes like proj-, squad-, help-, vendor-, etc.) to help users find relevant discussions.",
#     "score": 3,
#     "answer": "yes",
#     "reasoning": "Both responses list Slack channels organized by categories, but they contain significantly different channel sets with some overlap. The LLM response includes many more channels (200+) while the expected response has fewer channels but includes member counts and different organizational structure."
# }
# Evaluation results for prompt List all channels in the workspace:
#
# {'selected_expected_response': 'Here are all the channels in the Slack workspace:\n\nMain Company Channels:\n#general (201 members) - Main company-wide channel for announcements and team conversations\n#random (199 members) - Casual conversation and team jokes\n#help-it (196 members) - IT related queries\n#help-hr (191 members) - HR related queries\n#help-legal-risk-compliance (97 members) - Legal/risk/compliance queries\nEngineering & Tech Channels:\n#all-devs (132 members) - All engineers company-wide\n#plz-review (109 members) - Code review requests\n#eng-backend (102 members) - Backend engineering discussions\n#fe-gang (89 members) - Frontend engineering team\n#guild-backend (33 members) - Backend guild\n#guild-devx (132 members) - Developer experience guild\nProduct & Operations:\n#product (76 members) - Product management discussions\n#operations-service-model (4 members) - Operations organization\n#prod-onboarding (69 members) - Production onboarding\n#incident-response (97 members) - Incident response FAQ\nBusiness & Finance:\n#finance (37 members) - Finance workstream\n#business-team (4 members) - Business team discussions\n#intel (96 members) - Competitor and client intelligence\n#client-implementation-and-governance (3 members) - Client work\nTeam Squads:\n#squad-users (102 members) - User-focused squad\n#squad-lending (95 members) - Lending team\n#squad-mese (21 members) - Payments, Payees, Cards squad\n#squad-platform (106 members) - Platform squad\n#squad-data (98 members) - Data team\nSocial & Fun:\n#pet-pics (51 members) - Pet photos\n#foodlovers (44 members) - Food discussions\n#good-reads (41 members) - Blog post recommendations\n#run-club (41 members) - Running club\n#gains-club (20 members) - Gym and fitness\n#coffee-buddies (49 members) - Coffee meetups\nOffice Locations:\n#sydney-office (101 members) - Sydney office coordination\n#melbourne-office (8 members) - Melbourne office\n#india-office (58 members) - India office\nThe workspace has a total of 580+ channels covering everything from technical projects and production alerts to social clubs and office coordination. The channels are well-organized with clear naming conventions (prefixes like proj-, squad-, help-, vendor-, etc.) to help users find relevant discussions.', 'score': 3, 'answer': 'yes', 'reasoning': 'Both responses list Slack channels organized by categories, but they contain significantly different channel sets with some overlap. The LLM response includes many more channels (200+) while the expected response has fewer channels but includes member counts and different organizational structure.'}
# {'id': 'chatcmpl-e51bc5ee', 'created': 1751521046, 'model': 'apac.anthropic.claude-sonnet-4-20250514-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': '{\n    "selected_expected_response": "Here are all the public channels available in your Slack workspace:\\n\\nGeneral Channels\\n#general (202 members) - Main workspace channel for announcements and team-wide conversations\\n#random (200 members) - For everything else - team jokes, ideas, and GIFs\\nCore Business & Operations\\n#business-team (4 members) - Business team discussions, propositions, product, roadmap\\n#business-development (4 members) - Business development activities\\n#client-solutions (3 members) - Client solutions and differentiator discussions\\n#operations-service-model (4 members) - Operations organization and delivery\\n#pmo (1 member) - Project Management Office\\n#product-operations (88 members) - Product operations discussions\\nEngineering & Development\\n#all-devs (132 members) - All engineers company-wide\\n#eng-backend (102 members) - Backend engineering discussions\\n#fe-gang (90 members) - Frontend engineering discussions and PR review requests\\n#tech (1 member) - General tech discussions\\n#design (52 members) - Design updates, feedback, and questions\\nSquads & Teams\\n#squad-mese (21 members) - Payments, Payees, Cards Squad\\n#squad-users (102 members) - User onboarding squad\\n#squad-lending (95 members) - Lending squad\\n#squad-platform (107 members) - Platform squad\\n#squad-txb (125 members) - Transaction banking squad\\n#squad-data (98 members) - Data team requests and discussions\\n#squad-prod-ops (119 members) - Production operations support\\nHelp & Support Channels\\n#help-it (197 members) - IT related queries\\n#help-hr (192 members) - HR related queries\\n#help-legal-risk-compliance (97 members) - Legal/risk/compliance queries\\n#help-engineering (28 members) - Engineering related queries\\n#help-office-syd (64 members) - Sydney office related help\\nProduction & Monitoring\\n#prod-lending (75 members) - Production lending issues\\n#prod-txb (52 members) - Production TXB issues/discussions\\n#prod-platform-alerts (30 members) - Production platform alerts\\n#incident-response (98 members) - Incidents FAQs and response\\n#major-incident-comms (73 members) - Major incidents internal communications\\nSocial & Interest Groups\\n#pet-pics (54 members) - Pet photos\\n#foodlovers (43 members) - Food tips, recipes, events, news\\n#run-club (41 members) - Running club\\n#gains-club (20 members) - Gym and fitness related\\n#rock-enthusiasts (13 members) - Rock climbing\\n#formula-1-club (16 members) - Formula 1 discussions (no spoilers!)\\n#swim-club (20 members) - Swimming club\\n#cxnpl-tennis-club (14 members) - Tennis club\\nThere are 502 total public channels in your workspace, covering everything from core business operations to social activities and specialized project work.",\n    "score": 4,\n    "answer": "yes",\n    "reasoning": "Both responses provide comprehensive lists of public Slack channels organized by similar categories (squads, production, help, social, etc.). The LLM response covers the same channel types and includes many identical channel names, though it uses slightly different organization and includes some additional channels like project-specific ones that weren\'t in the expected response"\n}'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 1686, 'completion_tokens': 857, 'total_tokens': 2543}}
# {
#     "selected_expected_response": "Here are all the public channels available in your Slack workspace:\n\nGeneral Channels\n#general (202 members) - Main workspace channel for announcements and team-wide conversations\n#random (200 members) - For everything else - team jokes, ideas, and GIFs\nCore Business & Operations\n#business-team (4 members) - Business team discussions, propositions, product, roadmap\n#business-development (4 members) - Business development activities\n#client-solutions (3 members) - Client solutions and differentiator discussions\n#operations-service-model (4 members) - Operations organization and delivery\n#pmo (1 member) - Project Management Office\n#product-operations (88 members) - Product operations discussions\nEngineering & Development\n#all-devs (132 members) - All engineers company-wide\n#eng-backend (102 members) - Backend engineering discussions\n#fe-gang (90 members) - Frontend engineering discussions and PR review requests\n#tech (1 member) - General tech discussions\n#design (52 members) - Design updates, feedback, and questions\nSquads & Teams\n#squad-mese (21 members) - Payments, Payees, Cards Squad\n#squad-users (102 members) - User onboarding squad\n#squad-lending (95 members) - Lending squad\n#squad-platform (107 members) - Platform squad\n#squad-txb (125 members) - Transaction banking squad\n#squad-data (98 members) - Data team requests and discussions\n#squad-prod-ops (119 members) - Production operations support\nHelp & Support Channels\n#help-it (197 members) - IT related queries\n#help-hr (192 members) - HR related queries\n#help-legal-risk-compliance (97 members) - Legal/risk/compliance queries\n#help-engineering (28 members) - Engineering related queries\n#help-office-syd (64 members) - Sydney office related help\nProduction & Monitoring\n#prod-lending (75 members) - Production lending issues\n#prod-txb (52 members) - Production TXB issues/discussions\n#prod-platform-alerts (30 members) - Production platform alerts\n#incident-response (98 members) - Incidents FAQs and response\n#major-incident-comms (73 members) - Major incidents internal communications\nSocial & Interest Groups\n#pet-pics (54 members) - Pet photos\n#foodlovers (43 members) - Food tips, recipes, events, news\n#run-club (41 members) - Running club\n#gains-club (20 members) - Gym and fitness related\n#rock-enthusiasts (13 members) - Rock climbing\n#formula-1-club (16 members) - Formula 1 discussions (no spoilers!)\n#swim-club (20 members) - Swimming club\n#cxnpl-tennis-club (14 members) - Tennis club\nThere are 502 total public channels in your workspace, covering everything from core business operations to social activities and specialized project work.",
#     "score": 4,
#     "answer": "yes",
#     "reasoning": "Both responses provide comprehensive lists of public Slack channels organized by similar categories (squads, production, help, social, etc.). The LLM response covers the same channel types and includes many identical channel names, though it uses slightly different organization and includes some additional channels like project-specific ones that weren't in the expected response"
# }
# Evaluation results for prompt Show me all public channels:
#
# {'selected_expected_response': 'Here are all the public channels available in your Slack workspace:\n\nGeneral Channels\n#general (202 members) - Main workspace channel for announcements and team-wide conversations\n#random (200 members) - For everything else - team jokes, ideas, and GIFs\nCore Business & Operations\n#business-team (4 members) - Business team discussions, propositions, product, roadmap\n#business-development (4 members) - Business development activities\n#client-solutions (3 members) - Client solutions and differentiator discussions\n#operations-service-model (4 members) - Operations organization and delivery\n#pmo (1 member) - Project Management Office\n#product-operations (88 members) - Product operations discussions\nEngineering & Development\n#all-devs (132 members) - All engineers company-wide\n#eng-backend (102 members) - Backend engineering discussions\n#fe-gang (90 members) - Frontend engineering discussions and PR review requests\n#tech (1 member) - General tech discussions\n#design (52 members) - Design updates, feedback, and questions\nSquads & Teams\n#squad-mese (21 members) - Payments, Payees, Cards Squad\n#squad-users (102 members) - User onboarding squad\n#squad-lending (95 members) - Lending squad\n#squad-platform (107 members) - Platform squad\n#squad-txb (125 members) - Transaction banking squad\n#squad-data (98 members) - Data team requests and discussions\n#squad-prod-ops (119 members) - Production operations support\nHelp & Support Channels\n#help-it (197 members) - IT related queries\n#help-hr (192 members) - HR related queries\n#help-legal-risk-compliance (97 members) - Legal/risk/compliance queries\n#help-engineering (28 members) - Engineering related queries\n#help-office-syd (64 members) - Sydney office related help\nProduction & Monitoring\n#prod-lending (75 members) - Production lending issues\n#prod-txb (52 members) - Production TXB issues/discussions\n#prod-platform-alerts (30 members) - Production platform alerts\n#incident-response (98 members) - Incidents FAQs and response\n#major-incident-comms (73 members) - Major incidents internal communications\nSocial & Interest Groups\n#pet-pics (54 members) - Pet photos\n#foodlovers (43 members) - Food tips, recipes, events, news\n#run-club (41 members) - Running club\n#gains-club (20 members) - Gym and fitness related\n#rock-enthusiasts (13 members) - Rock climbing\n#formula-1-club (16 members) - Formula 1 discussions (no spoilers!)\n#swim-club (20 members) - Swimming club\n#cxnpl-tennis-club (14 members) - Tennis club\nThere are 502 total public channels in your workspace, covering everything from core business operations to social activities and specialized project work.', 'score': 4, 'answer': 'yes', 'reasoning': "Both responses provide comprehensive lists of public Slack channels organized by similar categories (squads, production, help, social, etc.). The LLM response covers the same channel types and includes many identical channel names, though it uses slightly different organization and includes some additional channels like project-specific ones that weren't in the expected response"}
# {'id': 'chatcmpl-139ff39a', 'created': 1751521050, 'model': 'apac.anthropic.claude-sonnet-4-20250514-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': '{\n    "selected_expected_response": "I successfully posted the message \\\\Hello team! From eval framework here.\\" to channel C08UFS9HMCN (which is the ai-slackbot-testing channel) at the timestamp...",\n    "score": 4,\n    "answer": "yes",\n    "reasoning": "Both responses confirm successful posting of the same message content. The LLM response lacks the specific channel ID, channel name, and timestamp details present in the expected response, but conveys the same core meaning of successful message posting"\n}'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 586, 'completion_tokens': 129, 'total_tokens': 715}}
# {
#     "selected_expected_response": "I successfully posted the message \\Hello team! From eval framework here.\" to channel C08UFS9HMCN (which is the ai-slackbot-testing channel) at the timestamp...",
#     "score": 4,
#     "answer": "yes",
#     "reasoning": "Both responses confirm successful posting of the same message content. The LLM response lacks the specific channel ID, channel name, and timestamp details present in the expected response, but conveys the same core meaning of successful message posting"
# }
# Evaluation results for prompt Post 'Hello team! From eval framework here.' to channel C08UFS9HMCN:
#
# {'selected_expected_response': 'I successfully posted the message \\Hello team! From eval framework here." to channel C08UFS9HMCN (which is the ai-slackbot-testing channel) at the timestamp...', 'score': 4, 'answer': 'yes', 'reasoning': 'Both responses confirm successful posting of the same message content. The LLM response lacks the specific channel ID, channel name, and timestamp details present in the expected response, but conveys the same core meaning of successful message posting'}
# {'id': 'chatcmpl-b55764d5', 'created': 1751521054, 'model': 'apac.anthropic.claude-sonnet-4-20250514-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': '{\n    "selected_expected_response": "It looks like a heart reaction has already been added to this message. The Slack API returned an \\"already_reacted\\" error, which means either you or someone else has already reacted to this message with a heart emoji.\\n\\nIf you\'d like to try a different reaction emoji, just let me know which one you\'d prefer!",\n    "score": 4,\n    "answer": "yes",\n    "reasoning": "Both responses correctly identify the \\"already_reacted\\" error and explain that a heart reaction was already added to the message. The LLM response is slightly more specific about the user having previously added the reaction, while the expected response offers additional help with alternative reactions, but the core meaning and error handling are essentially the same."\n}'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 716, 'completion_tokens': 177, 'total_tokens': 893}}
# {
#     "selected_expected_response": "It looks like a heart reaction has already been added to this message. The Slack API returned an \"already_reacted\" error, which means either you or someone else has already reacted to this message with a heart emoji.\n\nIf you'd like to try a different reaction emoji, just let me know which one you'd prefer!",
#     "score": 4,
#     "answer": "yes",
#     "reasoning": "Both responses correctly identify the \"already_reacted\" error and explain that a heart reaction was already added to the message. The LLM response is slightly more specific about the user having previously added the reaction, while the expected response offers additional help with alternative reactions, but the core meaning and error handling are essentially the same."
# }
# Evaluation results for prompt Add heart reaction to message at timestamp 1750300317.785949 in channel C08UFS9HMCN:
#
# {'selected_expected_response': 'It looks like a heart reaction has already been added to this message. The Slack API returned an "already_reacted" error, which means either you or someone else has already reacted to this message with a heart emoji.\n\nIf you\'d like to try a different reaction emoji, just let me know which one you\'d prefer!', 'score': 4, 'answer': 'yes', 'reasoning': 'Both responses correctly identify the "already_reacted" error and explain that a heart reaction was already added to the message. The LLM response is slightly more specific about the user having previously added the reaction, while the expected response offers additional help with alternative reactions, but the core meaning and error handling are essentially the same.'}
# {'id': 'chatcmpl-712362e8', 'created': 1751521058, 'model': 'apac.anthropic.claude-sonnet-4-20250514-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': '{\n    "selected_expected_response": "Perfect! I\'ve successfully replied to the thread with \\"Thanks for the update!\\" in channel C08UFS9HMCN. The reply was posted at timestamp 1751251060.214489 and is now part of the thread that started with message 1750300317.785949.",\n    "score": 4,\n    "answer": "yes",\n    "reasoning": "Both responses confirm the same core action was completed - replying to the thread with the specified message in the correct channel. The expected response includes additional technical details like timestamps and thread confirmation, but the LLM response captures the essential meaning with slightly more concise wording."\n}'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 621, 'completion_tokens': 157, 'total_tokens': 778}}
# {
#     "selected_expected_response": "Perfect! I've successfully replied to the thread with \"Thanks for the update!\" in channel C08UFS9HMCN. The reply was posted at timestamp 1751251060.214489 and is now part of the thread that started with message 1750300317.785949.",
#     "score": 4,
#     "answer": "yes",
#     "reasoning": "Both responses confirm the same core action was completed - replying to the thread with the specified message in the correct channel. The expected response includes additional technical details like timestamps and thread confirmation, but the LLM response captures the essential meaning with slightly more concise wording."
# }
# Evaluation results for prompt Reply to thread 1750300317.785949 in channel C08UFS9HMCN with 'Thanks for the update!':
#
# {'selected_expected_response': 'Perfect! I\'ve successfully replied to the thread with "Thanks for the update!" in channel C08UFS9HMCN. The reply was posted at timestamp 1751251060.214489 and is now part of the thread that started with message 1750300317.785949.', 'score': 4, 'answer': 'yes', 'reasoning': 'Both responses confirm the same core action was completed - replying to the thread with the specified message in the correct channel. The expected response includes additional technical details like timestamps and thread confirmation, but the LLM response captures the essential meaning with slightly more concise wording.'}
# {'id': 'chatcmpl-198ee593', 'created': 1751521067, 'model': 'apac.anthropic.claude-sonnet-4-20250514-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': '{\n    "selected_expected_response": "Here are all the replies in the thread starting with timestamp 1750300317.785949:\\n\\nThread Summary\\nTotal replies: 6 messages (including the original)\\nThread participants: 2 users\\nLatest reply: Just posted (1751251060.214489)\\n\\nMessages in order:\\nOriginal Message (1750300317.785949) - by Codex bot:\\n__ Random Message Alert! __\\nFun fact about octopuses having three hearts and blue blood! ____\\nTesting AI chatbot functionality\\nWritten on behalf of Alan Nguyen\\nReactions: __ (2), __ (1), __ (1)\\nReply 1 (1750743854.095189) - by User U08FUTB4QLC:\\n\\"Awesome, thats so cool!\\"\\nReply 2 (1750743906.601929) - by Codex bot:\\n\\"Thanks for the update!\\"\\nWritten on behalf of Mohitha Mohan\\nReply 3 (1750920418.327549) - by Codex bot:\\n\\"Thanks for the update!\\"\\nReply 4 (1750922035.122979) - by Codex bot:\\n\\"Thanks for the update!\\"\\nReply 5 (1751251060.214489) - by Codex bot:\\n\\"Thanks for the update!\\" (this is the reply we just posted)\\nThe thread shows good engagement with the original fun fact message, and several \\"Thanks for the update!\\" replies from the Codex bot.",\n    "score": 4,\n    "answer": "yes",\n    "reasoning": "Both responses contain the same core content about the octopus thread, including the original message, replies from users, and reaction information. The main differences are in formatting and the LLM response mentions 15 repetitions while the expected response shows 5 specific timestamps, but the essential information matches well"\n}'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 1071, 'completion_tokens': 466, 'total_tokens': 1537}}
# {
#     "selected_expected_response": "Here are all the replies in the thread starting with timestamp 1750300317.785949:\n\nThread Summary\nTotal replies: 6 messages (including the original)\nThread participants: 2 users\nLatest reply: Just posted (1751251060.214489)\n\nMessages in order:\nOriginal Message (1750300317.785949) - by Codex bot:\n__ Random Message Alert! __\nFun fact about octopuses having three hearts and blue blood! ____\nTesting AI chatbot functionality\nWritten on behalf of Alan Nguyen\nReactions: __ (2), __ (1), __ (1)\nReply 1 (1750743854.095189) - by User U08FUTB4QLC:\n\"Awesome, thats so cool!\"\nReply 2 (1750743906.601929) - by Codex bot:\n\"Thanks for the update!\"\nWritten on behalf of Mohitha Mohan\nReply 3 (1750920418.327549) - by Codex bot:\n\"Thanks for the update!\"\nReply 4 (1750922035.122979) - by Codex bot:\n\"Thanks for the update!\"\nReply 5 (1751251060.214489) - by Codex bot:\n\"Thanks for the update!\" (this is the reply we just posted)\nThe thread shows good engagement with the original fun fact message, and several \"Thanks for the update!\" replies from the Codex bot.",
#     "score": 4,
#     "answer": "yes",
#     "reasoning": "Both responses contain the same core content about the octopus thread, including the original message, replies from users, and reaction information. The main differences are in formatting and the LLM response mentions 15 repetitions while the expected response shows 5 specific timestamps, but the essential information matches well"
# }
# Evaluation results for prompt Get all replies from thread 1750300317.785949 in channel C08UFS9HMCN:
#
# {'selected_expected_response': 'Here are all the replies in the thread starting with timestamp 1750300317.785949:\n\nThread Summary\nTotal replies: 6 messages (including the original)\nThread participants: 2 users\nLatest reply: Just posted (1751251060.214489)\n\nMessages in order:\nOriginal Message (1750300317.785949) - by Codex bot:\n__ Random Message Alert! __\nFun fact about octopuses having three hearts and blue blood! ____\nTesting AI chatbot functionality\nWritten on behalf of Alan Nguyen\nReactions: __ (2), __ (1), __ (1)\nReply 1 (1750743854.095189) - by User U08FUTB4QLC:\n"Awesome, thats so cool!"\nReply 2 (1750743906.601929) - by Codex bot:\n"Thanks for the update!"\nWritten on behalf of Mohitha Mohan\nReply 3 (1750920418.327549) - by Codex bot:\n"Thanks for the update!"\nReply 4 (1750922035.122979) - by Codex bot:\n"Thanks for the update!"\nReply 5 (1751251060.214489) - by Codex bot:\n"Thanks for the update!" (this is the reply we just posted)\nThe thread shows good engagement with the original fun fact message, and several "Thanks for the update!" replies from the Codex bot.', 'score': 4, 'answer': 'yes', 'reasoning': 'Both responses contain the same core content about the octopus thread, including the original message, replies from users, and reaction information. The main differences are in formatting and the LLM response mentions 15 repetitions while the expected response shows 5 specific timestamps, but the essential information matches well'}
# {'id': 'chatcmpl-f54d600d', 'created': 1751521090, 'model': 'apac.anthropic.claude-sonnet-4-20250514-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': '{\n    "selected_expected_response": "Here are all the users in your Slack workspace:\\n\\nWorkspace Members (160 total users)\\nLeadership & Management:\\n\\nCameron Meindl (@cameron_meindl) - Field CTO Constantinople\\nKeerthi Iyengar (@keerthi_iyengar) - Chief Operating Officer\\nDanielle Ross (@danielle_ross) - Head of People\\nLuke Raven (@luke_raven) - Head of FinCrime & Fraud\\nTony Bolcina (@tony_bolcina) - Head of Design\\nEngineering Managers:\\n\\nMaciej Adamczak (@maciej_adamczak) - UX Squad: Platform - Engineering Manager\\nKausthubh Adhikari (@kausthubh_adhikari) - Engineering Manager - UX Squad Mobile\\nRohit Khandelwal (@rohit_khandelwal) - Engineering Manager - TXB squad\\nSenior Engineers & Technical Leads:\\n\\nOscar Fawkes (@oscar_fawkes) - GAI TL\\nEvan Kohilas (@evan_kohilas) - Senior Software Engineer on the Platform Squad\\nShubham Ranu (@shubham_ranu) - Senior Software Engineer - Users & Onboarding\\nUtkarsh Sharma (@utkarsh_sharma) - Senior Software Engineer\\nMrinal Pradhan (@mrinal_pradhan) - Senior Software Engineer\\nSoftware Engineers:\\n\\nCampbell Wang (@campbell_wang) - Junior Software Engineer (with quite the title collection! __)\\nMeraj Ahmad (@meraj_ahmad) - Software Engineering - Users & Onboarding\\nNitin Mishra (@nitin_mishra) - Software Engineer\\nDhairya Punjabi (@dhairya_punjabi) - Senior Software Developer\\nIshaank Gupta (@ishaank_gupta) - Senior FE @ Onboarding\\nAniket Chaudhary (@aniket_chaudhary) - Senior FE @txb (and water connoisseur! __)\\nThoughtWorks Team:\\n\\nNeha Aggarwal, Shubham Kumar, Rishi Dahiya, Ankit Chaudhary, Shivam Kapoor, Komal Bansal, Umair Shaik, Suresh Kumar Putchala, Manish Gupta, Aashita Trehan, Bhumanyu Kumar, Brijesh Gajjar, Adarsh Jegadeesan, Camilo Diaz, Luke McCartin, Trupthi Mahesh, Arun Chakkaravarthi M, Praveen Prasannan\\nSpecialists & Other Roles:\\n\\nAlan Nguyen (@alan_nguyen) - Forward deployed prompt engineer __\\nJeremy Smith (@jeremy_smith) - Crab __\\nBlake Belcastro (@blake_belcastro) - Chief Widget Officer\\nAlec Zhang (@alec_zhang) - Where\'s the lamb sauce\\nTheon Ho (@theon_ho) - Laksa King\\nAndy Truong (@andy_truong) - Progamer\\nGautham Ontri (@gautham_ontri) - Internet Mechanic\\nJordan Yoong (@jordan_yoong) - Internet security guard\\nBenjamin Staite (@benjamin_staite) - Head of Basketball Operations\\nFun Titles & Personalities:\\n\\nStella Reeve (@stella_reeve) - Product Ops (his name is Beans)\\nLawrence Shi (@lawrence_shi) - i live for hardstyle baby\\nIdo Zamir (@ido_zamir) - Old Man with Soup\\nLachlan McGrath (@lachlan_mcgrath) - Banh Mi Enthusiast\\nGrace Gleeson (@grace_gleeson) - CXNPL Botanist\\nHayley Rodgers (@hayley_rodgers) - kitchen fairy\\nFergus Charles (@fergus_charles) - In house chef _____\\nAlexandra Maher (@alexandra_maher) - live laugh loan no longer\\nKaito Nakamichi (@kaito_nakamichi) - average volatility enthusiast\\nHeather Prenter (@heather_prenter) - Heather from Credit\\nArun Manivannan (@arun_manivannan) - master of awkward conversations\\nAnd many more talented individuals across various teams including Data Analytics, Legal, Talent Acquisition, Client Delivery, AWS, and other specialized roles!\\n\\nThe workspace has a great mix of technical talent, leadership, and some wonderfully creative job titles! __",\n    "score": 3,\n    "answer": "yes",\n    "reasoning": "Both responses provide comprehensive lists of workspace users with names and titles, fulfilling the core request. However, the LLM response uses a simple alphabetical table format while the expected response categorizes users by role and adds commentary, representing significantly different organizational approaches that affect completeness and user experience"\n}'}}], 'object': 'chat.compl ...
# {
#     "selected_expected_response": "Here are all the users in your Slack workspace:\n\nWorkspace Members (160 total users)\nLeadership & Management:\n\nCameron Meindl (@cameron_meindl) - Field CTO Constantinople\nKeerthi Iyengar (@keerthi_iyengar) - Chief Operating Officer\nDanielle Ross (@danielle_ross) - Head of People\nLuke Raven (@luke_raven) - Head of FinCrime & Fraud\nTony Bolcina (@tony_bolcina) - Head of Design\nEngineering Managers:\n\nMaciej Adamczak (@maciej_adamczak) - UX Squad: Platform - Engineering Manager\nKausthubh Adhikari (@kausthubh_adhikari) - Engineering Manager - UX Squad Mobile\nRohit Khandelwal (@rohit_khandelwal) - Engineering Manager - TXB squad\nSenior Engineers & Technical Leads:\n\nOscar Fawkes (@oscar_fawkes) - GAI TL\nEvan Kohilas (@evan_kohilas) - Senior Software Engineer on the Platform Squad\nShubham Ranu (@shubham_ranu) - Senior Software Engineer - Users & Onboarding\nUtkarsh Sharma (@utkarsh_sharma) - Senior Software Engineer\nMrinal Pradhan (@mrinal_pradhan) - Senior Software Engineer\nSoftware Engineers:\n\nCampbell Wang (@campbell_wang) - Junior Software Engineer (with quite the title collection! __)\nMeraj Ahmad (@meraj_ahmad) - Software Engineering - Users & Onboarding\nNitin Mishra (@nitin_mishra) - Software Engineer\nDhairya Punjabi (@dhairya_punjabi) - Senior Software Developer\nIshaank Gupta (@ishaank_gupta) - Senior FE @ Onboarding\nAniket Chaudhary (@aniket_chaudhary) - Senior FE @txb (and water connoisseur! __)\nThoughtWorks Team:\n\nNeha Aggarwal, Shubham Kumar, Rishi Dahiya, Ankit Chaudhary, Shivam Kapoor, Komal Bansal, Umair Shaik, Suresh Kumar Putchala, Manish Gupta, Aashita Trehan, Bhumanyu Kumar, Brijesh Gajjar, Adarsh Jegadeesan, Camilo Diaz, Luke McCartin, Trupthi Mahesh, Arun Chakkaravarthi M, Praveen Prasannan\nSpecialists & Other Roles:\n\nAlan Nguyen (@alan_nguyen) - Forward deployed prompt engineer __\nJeremy Smith (@jeremy_smith) - Crab __\nBlake Belcastro (@blake_belcastro) - Chief Widget Officer\nAlec Zhang (@alec_zhang) - Where's the lamb sauce\nTheon Ho (@theon_ho) - Laksa King\nAndy Truong (@andy_truong) - Progamer\nGautham Ontri (@gautham_ontri) - Internet Mechanic\nJordan Yoong (@jordan_yoong) - Internet security guard\nBenjamin Staite (@benjamin_staite) - Head of Basketball Operations\nFun Titles & Personalities:\n\nStella Reeve (@stella_reeve) - Product Ops (his name is Beans)\nLawrence Shi (@lawrence_shi) - i live for hardstyle baby\nIdo Zamir (@ido_zamir) - Old Man with Soup\nLachlan McGrath (@lachlan_mcgrath) - Banh Mi Enthusiast\nGrace Gleeson (@grace_gleeson) - CXNPL Botanist\nHayley Rodgers (@hayley_rodgers) - kitchen fairy\nFergus Charles (@fergus_charles) - In house chef _____\nAlexandra Maher (@alexandra_maher) - live laugh loan no longer\nKaito Nakamichi (@kaito_nakamichi) - average volatility enthusiast\nHeather Prenter (@heather_prenter) - Heather from Credit\nArun Manivannan (@arun_manivannan) - master of awkward conversations\nAnd many more talented individuals across various teams including Data Analytics, Legal, Talent Acquisition, Client Delivery, AWS, and other specialized roles!\n\nThe workspace has a great mix of technical talent, leadership, and some wonderfully creative job titles! __",
#     "score": 3,
#     "answer": "yes",
#     "reasoning": "Both responses provide comprehensive lists of workspace users with names and titles, fulfilling the core request. However, the LLM response uses a simple alphabetical table format while the expected response categorizes users by role and adds commentary, representing significantly different organizational approaches that affect completeness and user experience"
# }
# Evaluation results for prompt Show me all the users in the workspace:
#
# {'selected_expected_response': "Here are all the users in your Slack workspace:\n\nWorkspace Members (160 total users)\nLeadership & Management:\n\nCameron Meindl (@cameron_meindl) - Field CTO Constantinople\nKeerthi Iyengar (@keerthi_iyengar) - Chief Operating Officer\nDanielle Ross (@danielle_ross) - Head of People\nLuke Raven (@luke_raven) - Head of FinCrime & Fraud\nTony Bolcina (@tony_bolcina) - Head of Design\nEngineering Managers:\n\nMaciej Adamczak (@maciej_adamczak) - UX Squad: Platform - Engineering Manager\nKausthubh Adhikari (@kausthubh_adhikari) - Engineering Manager - UX Squad Mobile\nRohit Khandelwal (@rohit_khandelwal) - Engineering Manager - TXB squad\nSenior Engineers & Technical Leads:\n\nOscar Fawkes (@oscar_fawkes) - GAI TL\nEvan Kohilas (@evan_kohilas) - Senior Software Engineer on the Platform Squad\nShubham Ranu (@shubham_ranu) - Senior Software Engineer - Users & Onboarding\nUtkarsh Sharma (@utkarsh_sharma) - Senior Software Engineer\nMrinal Pradhan (@mrinal_pradhan) - Senior Software Engineer\nSoftware Engineers:\n\nCampbell Wang (@campbell_wang) - Junior Software Engineer (with quite the title collection! __)\nMeraj Ahmad (@meraj_ahmad) - Software Engineering - Users & Onboarding\nNitin Mishra (@nitin_mishra) - Software Engineer\nDhairya Punjabi (@dhairya_punjabi) - Senior Software Developer\nIshaank Gupta (@ishaank_gupta) - Senior FE @ Onboarding\nAniket Chaudhary (@aniket_chaudhary) - Senior FE @txb (and water connoisseur! __)\nThoughtWorks Team:\n\nNeha Aggarwal, Shubham Kumar, Rishi Dahiya, Ankit Chaudhary, Shivam Kapoor, Komal Bansal, Umair Shaik, Suresh Kumar Putchala, Manish Gupta, Aashita Trehan, Bhumanyu Kumar, Brijesh Gajjar, Adarsh Jegadeesan, Camilo Diaz, Luke McCartin, Trupthi Mahesh, Arun Chakkaravarthi M, Praveen Prasannan\nSpecialists & Other Roles:\n\nAlan Nguyen (@alan_nguyen) - Forward deployed prompt engineer __\nJeremy Smith (@jeremy_smith) - Crab __\nBlake Belcastro (@blake_belcastro) - Chief Widget Officer\nAlec Zhang (@alec_zhang) - Where's the lamb sauce\nTheon Ho (@theon_ho) - Laksa King\nAndy Truong (@andy_truong) - Progamer\nGautham Ontri (@gautham_ontri) - Internet Mechanic\nJordan Yoong (@jordan_yoong) - Internet security guard\nBenjamin Staite (@benjamin_staite) - Head of Basketball Operations\nFun Titles & Personalities:\n\nStella Reeve (@stella_reeve) - Product Ops (his name is Beans)\nLawrence Shi (@lawrence_shi) - i live for hardstyle baby\nIdo Zamir (@ido_zamir) - Old Man with Soup\nLachlan McGrath (@lachlan_mcgrath) - Banh Mi Enthusiast\nGrace Gleeson (@grace_gleeson) - CXNPL Botanist\nHayley Rodgers (@hayley_rodgers) - kitchen fairy\nFergus Charles (@fergus_charles) - In house chef _____\nAlexandra Maher (@alexandra_maher) - live laugh loan no longer\nKaito Nakamichi (@kaito_nakamichi) - average volatility enthusiast\nHeather Prenter (@heather_prenter) - Heather from Credit\nArun Manivannan (@arun_manivannan) - master of awkward conversations\nAnd many more talented individuals across various teams including Data Analytics, Legal, Talent Acquisition, Client Delivery, AWS, and other specialized roles!\n\nThe workspace has a great mix of technical talent, leadership, and some wonderfully creative job titles! __", 'score': 3, 'answer': 'yes', 'reasoning': 'Both responses provide comprehensive lists of workspace users with names and titles, fulfilling the core request. However, the LLM response uses a simple alphabetical table format while the expected response categorizes users by role and adds commentary, representing significantly different organizational approaches that affect completeness and user experience'}
# {'id': 'chatcmpl-0260656e', 'created': 1751521097, 'model': 'apac.anthropic.claude-sonnet-4-20250514-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': '{\n    "selected_expected_response": "Here are the detailed profile information for user U08FUTB4QLC:\\n\\nProfile Details for Mohitha Mohan\\nBasic Information:\\n\\nReal Name: Mohitha Mohan\\nDisplay Name: Mohitha Mohan\\nEmail: Mohitha@cxnpl.com\\nUser ID: U08FUTB4QLC\\nUsername: @mohitha_mohan\\nProfile Status:\\n\\nTitle: (Not specified)\\nStatus Text: (Currently empty)\\nStatus Emoji: (None set)\\nContact Information:\\n\\nPhone: (Not provided)\\nSkype: (Not provided)\\nProfile Images:\\n\\nHas Custom Image: Yes\\nAvatar Hash: fb39e0e7d7e7\\nProfile Image: Available in multiple sizes (24px to 1024px)\\nAdditional Details:\\n\\nFirst Name: Mohitha\\nLast Name: Mohan\\nHuddle State: Default (not in a huddle)\\nThis user appears to be one of the team members at CXNPL (based on their email domain) and was one of the participants in the thread we looked at earlier, where they replied \\"Awesome, thats so cool!\\" to the octopus fun fact message.",\n    "score": 4,\n    "answer": "yes",\n    "reasoning": "Both responses contain the same core profile information including name, email, user ID, and status details. The expected response includes additional technical details like username, avatar hash, and contextual information about the user\'s participation in conversations, while the LLM response is more concise but covers all the essential profile elements accurately"\n}'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 919, 'completion_tokens': 395, 'total_tokens': 1314}}
# {
# ...
# {'id': 'chatcmpl-f3bf9ea9', 'created': 1751521312, 'model': 'apac.anthropic.claude-sonnet-4-20250514-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': '{\n    "selected_expected_response": "I\'ve successfully retrieved the recent messages from the ytg channel. Here\'s a summary of the recent activity:\\n\\nRecent Messages from the YTG Channel\\nThe ytg channel appears to be a social group for women at the company (\\"Young, Talented, Gorgeous\\" or similar). Here are the key recent activities:\\n\\nMost Recent Messages:\\nUpcoming Dinner Plans - Someone mentioned wrapping up a call and leaving the office soon, with people confirming their attendance for \\"tonight\\" with checking hands and raised hand reactions.\\nRestaurant Booking - Ross has booked a place and shared an image, with people reacting positively to indicate they\'re interested in attending.\\nDate Planning - Discussion about May 14th working for most people, with many positive reactions.\\nDinner Suggestion - A message about it being time for another dinner, which received lots of heart reactions and positive responses.\\nNail Salon Recommendation - Someone shared a location near the office for nail services (blancblue nail & beauty in Haymarket).\\nSocial Sports Information - A PSA about Urban Rec offering free registration for women to join social sports teams in Sydney.\\nBottomless Brunch Planning - Multiple detailed messages about organizing a \\"CXNPLadies\\" bottomless brunch at Ho Jiak Town Hall, including:\\nMenu details and pricing ($88 each for 9 courses + unlimited drinks)\\nPoll for date selection (Feb 14 dinner vs Feb 15 brunch)\\nDiscussion about alternative venues for those not wanting alcohol/expensive options\\nPromotions Celebration - Congratulatory messages celebrating promotions and role changes of several women in the group.\\nFitness/Sports - Messages about borrowing workout clothes and charity walk participation.\\nThe channel appears very active with social planning, workplace celebrations, and mutual support among the female employees.",\n    "score": 1,\n    "answer": "no",\n    "reasoning": "The LLM response states that the ytg channel was not found and offers troubleshooting suggestions, while the expected response provides detailed channel messages and content. These responses have completely opposite meanings - one indicates failure to access the channel while the other shows successful retrieval of specific messages"\n}'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 1029, 'completion_tokens': 505, 'total_tokens': 1534}}
# {
#     "selected_expected_response": "I've successfully retrieved the recent messages from the ytg channel. Here's a summary of the recent activity:\n\nRecent Messages from the YTG Channel\nThe ytg channel appears to be a social group for women at the company (\"Young, Talented, Gorgeous\" or similar). Here are the key recent activities:\n\nMost Recent Messages:\nUpcoming Dinner Plans - Someone mentioned wrapping up a call and leaving the office soon, with people confirming their attendance for \"tonight\" with checking hands and raised hand reactions.\nRestaurant Booking - Ross has booked a place and shared an image, with people reacting positively to indicate they're interested in attending.\nDate Planning - Discussion about May 14th working for most people, with many positive reactions.\nDinner Suggestion - A message about it being time for another dinner, which received lots of heart reactions and positive responses.\nNail Salon Recommendation - Someone shared a location near the office for nail services (blancblue nail & beauty in Haymarket).\nSocial Sports Information - A PSA about Urban Rec offering free registration for women to join social sports teams in Sydney.\nBottomless Brunch Planning - Multiple detailed messages about organizing a \"CXNPLadies\" bottomless brunch at Ho Jiak Town Hall, including:\nMenu details and pricing ($88 each for 9 courses + unlimited drinks)\nPoll for date selection (Feb 14 dinner vs Feb 15 brunch)\nDiscussion about alternative venues for those not wanting alcohol/expensive options\nPromotions Celebration - Congratulatory messages celebrating promotions and role changes of several women in the group.\nFitness/Sports - Messages about borrowing workout clothes and charity walk participation.\nThe channel appears very active with social planning, workplace celebrations, and mutual support among the female employees.",
#     "score": 1,
#     "answer": "no",
#     "reasoning": "The LLM response states that the ytg channel was not found and offers troubleshooting suggestions, while the expected response provides detailed channel messages and content. These responses have completely opposite meanings - one indicates failure to access the channel while the other shows successful retrieval of specific messages"
# }
# Evaluation results for prompt Get recent messages from the ytg channel:
#
# {'selected_expected_response': 'I\'ve successfully retrieved the recent messages from the ytg channel. Here\'s a summary of the recent activity:\n\nRecent Messages from the YTG Channel\nThe ytg channel appears to be a social group for women at the company ("Young, Talented, Gorgeous" or similar). Here are the key recent activities:\n\nMost Recent Messages:\nUpcoming Dinner Plans - Someone mentioned wrapping up a call and leaving the office soon, with people confirming their attendance for "tonight" with checking hands and raised hand reactions.\nRestaurant Booking - Ross has booked a place and shared an image, with people reacting positively to indicate they\'re interested in attending.\nDate Planning - Discussion about May 14th working for most people, with many positive reactions.\nDinner Suggestion - A message about it being time for another dinner, which received lots of heart reactions and positive responses.\nNail Salon Recommendation - Someone shared a location near the office for nail services (blancblue nail & beauty in Haymarket).\nSocial Sports Information - A PSA about Urban Rec offering free registration for women to join social sports teams in Sydney.\nBottomless Brunch Planning - Multiple detailed messages about organizing a "CXNPLadies" bottomless brunch at Ho Jiak Town Hall, including:\nMenu details and pricing ($88 each for 9 courses + unlimited drinks)\nPoll for date selection (Feb 14 dinner vs Feb 15 brunch)\nDiscussion about alternative venues for those not wanting alcohol/expensive options\nPromotions Celebration - Congratulatory messages celebrating promotions and role changes of several women in the group.\nFitness/Sports - Messages about borrowing workout clothes and charity walk participation.\nThe channel appears very active with social planning, workplace celebrations, and mutual support among the female employees.', 'score': 1, 'answer': 'no', 'reasoning': 'The LLM response states that the ytg channel was not found and offers troubleshooting suggestions, while the expected response provides detailed channel messages and content. These responses have completely opposite meanings - one indicates failure to access the channel while the other shows successful retrieval of specific messages'}
# {'id': 'chatcmpl-43f7054f', 'created': 1751521315, 'model': 'apac.anthropic.claude-sonnet-4-20250514-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': '{\n    "selected_expected_response": "Perfect! I\'ve successfully posted the message \\"Meeting in 5 minutes - from eval framework\\" to the ai-slackbot-testing channel. The message was posted with timestamp 1751349675.278699 and appears to have been sent from the Codex bot account.",\n    "score": 4,\n    "answer": "yes",\n    "reasoning": "Both responses confirm successful posting of the exact same message to the same channel. The expected response includes additional technical details like timestamp and bot account information, but the core meaning and confirmation of task completion are identical."\n}'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 614, 'completion_tokens': 139, 'total_tokens': 753}}
# {
#     "selected_expected_response": "Perfect! I've successfully posted the message \"Meeting in 5 minutes - from eval framework\" to the ai-slackbot-testing channel. The message was posted with timestamp 1751349675.278699 and appears to have been sent from the Codex bot account.",
#     "score": 4,
#     "answer": "yes",
#     "reasoning": "Both responses confirm successful posting of the exact same message to the same channel. The expected response includes additional technical details like timestamp and bot account information, but the core meaning and confirmation of task completion are identical."
# }
# Evaluation results for prompt Post 'Meeting in 5 minutes - from eval framework' to ai-slackbot-testing channel:
#
# {'selected_expected_response': 'Perfect! I\'ve successfully posted the message "Meeting in 5 minutes - from eval framework" to the ai-slackbot-testing channel. The message was posted with timestamp 1751349675.278699 and appears to have been sent from the Codex bot account.', 'score': 4, 'answer': 'yes', 'reasoning': 'Both responses confirm successful posting of the exact same message to the same channel. The expected response includes additional technical details like timestamp and bot account information, but the core meaning and confirmation of task completion are identical.'}
# {'id': 'chatcmpl-1dfaeb8b', 'created': 1751521319, 'model': 'apac.anthropic.claude-sonnet-4-20250514-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': '{\n    "selected_expected_response": "Great! I\'ve successfully added a thumbs up (__) reaction to the message with timestamp 1751349675.278699 in the ai-slackbot-testing channel. The reaction has been applied to the \\"Meeting in 5 minutes - from eval framework\\" message.",\n    "score": 1,\n    "answer": "no",\n    "reasoning": "The LLM response indicates failure to add the reaction due to channel not being found, while the expected response indicates successful completion of the task. These responses convey completely opposite outcomes and meanings"\n}'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 783, 'completion_tokens': 137, 'total_tokens': 920}}
# {
#     "selected_expected_response": "Great! I've successfully added a thumbs up (__) reaction to the message with timestamp 1751349675.278699 in the ai-slackbot-testing channel. The reaction has been applied to the \"Meeting in 5 minutes - from eval framework\" message.",
#     "score": 1,
#     "answer": "no",
#     "reasoning": "The LLM response indicates failure to add the reaction due to channel not being found, while the expected response indicates successful completion of the task. These responses convey completely opposite outcomes and meanings"
# }
# Evaluation results for prompt Add thumbsup to message 1751349675.278699 in ai-slackbot-testing channel:
#
# {'selected_expected_response': 'Great! I\'ve successfully added a thumbs up (__) reaction to the message with timestamp 1751349675.278699 in the ai-slackbot-testing channel. The reaction has been applied to the "Meeting in 5 minutes - from eval framework" message.', 'score': 1, 'answer': 'no', 'reasoning': 'The LLM response indicates failure to add the reaction due to channel not being found, while the expected response indicates successful completion of the task. These responses convey completely opposite outcomes and meanings'}
# {'id': 'chatcmpl-9e60c26c', 'created': 1751521323, 'model': 'apac.anthropic.claude-sonnet-4-20250514-v1:0', 'system_fingerprint': 'fp', 'choices': [{'index': 0, 'finish_reason': 'stop', 'logprobs': None, 'message': {'role': 'assistant', 'content': '{\n    "selected_expected_response": "Perfect! I\'ve successfully replied \\"Will be there!\\" to the thread with timestamp 1751349675.278699 in the ai-slackbot-testing channel. The reply was posted with timestamp 1751349872.760909 and is now part of that message thread.",\n    "score": 4,\n    "answer": "yes",\n    "reasoning": "Both responses confirm successful completion of the same task - replying to a specific thread in the ai-slackbot-testing channel with the required message. The LLM response conveys the core meaning effectively, though it\'s less detailed than the expected response which includes specific timestamps and additional confirmation details."\n}'}}], 'object': 'chat.completion', 'usage': {'prompt_tokens': 621, 'completion_tokens': 160, 'total_tokens': 781}}
# {
#     "selected_expected_response": "Perfect! I've successfully replied \"Will be there!\" to the thread with timestamp 1751349675.278699 in the ai-slackbot-testing channel. The reply was posted with timestamp 1751349872.760909 and is now part of that message thread.",
#     "score": 4,
#     "answer": "yes",
#     "reasoning": "Both responses confirm successful completion of the same task - replying to a specific thread in the ai-slackbot-testing channel with the required message. The LLM response conveys the core meaning effectively, though it's less detailed than the expected response which includes specific timestamps and additional confirmation details."
# }
# Evaluation results for prompt Reply 'Will be there! from eval framework' to thread 1751349675.278699 in ai-slackbot-testing channel:
#
# {'selected_expected_response': 'Perfect! I\'ve successfully replied "Will be there!" to the thread with timestamp 1751349675.278699 in the ai-slackbot-testing channel. The reply was posted with timestamp 1751349872.760909 and is now part of that message thread.', 'score': 4, 'answer': 'yes', 'reasoning': "Both responses confirm successful completion of the same task - replying to a specific thread in the ai-slackbot-testing channel with the required message. The LLM response conveys the core meaning effectively, though it's less detailed than the expected response which includes specific timestamps and additional confirmation details."}
# {'detail': '404: Model not found'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[93], line 36
#      32 # print(f"Evaluation results for prompt {prompt}: {result}")
#      34 print(result)
# ---> 36 if result and result["choices"]:
#      37     eval_result = result["choices"][0]["message"]["content"]
#      38     print(eval_result)
#
# KeyError: 'choices'

# %% [markdown]
# ## Retrieve All the Results and Average them out

# %%
# Get all CSV files in eval_output directory
csv_files = glob.glob('eval_output/eval_results_*.csv')
print(f"Found {len(csv_files)} CSV files: {csv_files}")

# Read all CSV files into a list of DataFrames
dfs = []
for file in csv_files:
    df = pd.read_csv(file)
    dfs.append(df)
    print(f"Loaded {file} with {len(df)} rows")

print(dfs)
# Out:
# Found 3 CSV files: ['eval_output/eval_results_2.csv', 'eval_output/eval_results_3.csv', 'eval_output/eval_results_1.csv']
# Loaded eval_output/eval_results_2.csv with 20 rows
# Loaded eval_output/eval_results_3.csv with 20 rows
# Loaded eval_output/eval_results_1.csv with 20 rows
# [                                               prompt  \
# 0                  List all channels in the workspace
# 1                         Show me all public channels
# 2   Post 'Hello team! From eval framework here.' t...
# 3   Add heart reaction to message at timestamp 175...
# 4   Reply to thread 1750300317.785949 in channel C...
# 5   Get all replies from thread 1750300317.785949 ...
# 6              Show me all the users in the workspace
# 7            Get profile details for user U08FUTB4QLC
# 8         Search for messages containing 'mcp server'
# 9            Get recent messages from the ytg channel
# 10  Post 'Meeting in 5 minutes - from eval framewo...
# 11  Add thumbsup to message 1751349675.278699 in a...
# 12  Reply 'Will be there! from eval framework' to ...
# 13  Show thread replies for 1751349675.278699  in ...
# 14              Get profile details for Mohitha Mohan
# 15  Search for messages containing 'regex' from Os...
# 16            Search for food safari in sydney-office
# 17                 Get profile details for John Smith
# 18  Get me recent messages from the trump-supporte...
# 19                    Search for "petrichor" on slack
#
#                                              model  \
# 0   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 1   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 2   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 3   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 4   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 5   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 6   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 7   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 8   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 9   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 10  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 11  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 12  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 13  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 14  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 15  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 16  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 17  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 18  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 19  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
#
#                                              response  \
# 0   Here's a list of all the channels in the works...
# 1   I've retrieved a list of all public channels i...
# 2   I've posted the message "Hello team! From eval...
# 3   I tried to add a heart reaction to the message...
# 4   I've replied "Thanks for the update!" to the t...
# 5   # Thread Replies in Channel C08UFS9HMCN\n\nI'v...
# 6   # Slack Workspace Users\n\nHere's a list of al...
# 7   # User Profile: Mohitha Mohan\n\n## Basic Info...
# 8   I searched for messages containing 'mcp server...
# 9   I'll get the recent messages from the "ytg" ch...
# 10  I've posted the message "Meeting in 5 minutes ...
# 11  I apologize, but I was unable to add the thumb...
# 12  I've replied to the thread in the ai-slackbot-...
# 13  I'm unable to fetch the thread replies for the...
# 14  # Mohitha Mohan's Profile Details\n\n**Basic I...
# 15  I searched for messages containing 'regex' fro...
# 16  # Food Safari in Sydney Office\n\nBased on the...
# 17  I was not able to find profile details for "Jo...
# 18  I'm sorry, but I couldn't retrieve messages fr...
# 19  I searched for "petrichor" on Slack and found ...
#
#                            selected_expected_response  score answer  \
# 0   Here are all the channels in the Slack workspa...      4    yes
# 1   Here are all the public channels available in ...      3    yes
# 2   I successfully posted the message \Hello team!...      4    yes
# 3   It looks like a heart reaction has already bee...      5    yes
# 4   Perfect! I've successfully replied to the thre...      4    yes
# 5   Here are all the replies in the thread startin...      4    yes
# 6   Here are all the users in your Slack workspace...      4    yes
# 7   Here are the detailed profile information for ...      4    yes
# 8   Here are the search results for messages conta...      4    yes
# 9   I've successfully retrieved the recent message...      2     no
# 10  Perfect! I've successfully posted the message ...      4    yes
# 11                                                NaN      3    yes
# 12  Perfect! I've successfully replied "Will be th...      4    yes
# 13  Here are the thread replies for message 175134...      2     no
# 14  Here are the profile details for Mohitha Mohan...      3    yes
# 15  I found 3 messages from Oscar Fawkes containin...      2     no
# 16  Great! I found 10 messages about "Food Safari"...      3    yes
# 17  It looks like I couldn't find a user with that...      4    yes
# 18  I searched through all the channels in your Sl...      4    yes
# 19  The search for "petrichor" on Slack returned n...      3    yes
#
#                                             reasoning
# 0   The LLM response matches Expected Response 1 v...
# 1   The LLM response partially matches the expecte...
# 2   The LLM response conveys the same core action ...
# 3   The LLM response perfectly captures the core m...
# 4   The LLM response conveys the same core action ...
# 5   The LLM response captures the core content of ...
# 6   The LLM response matches the expected response...
# 7   The LLM response matches the core information ...
# 8   The LLM response accurately summarizes the key...
# 9   While both responses retrieve and present mess...
# 10  The LLM response conveys the same core meaning...
# 11  The LLM response indicates an error occurred w...
# 12  The LLM response conveys the same core action ...
# 13  The LLM response indicates an inability to acc...
# 14  The LLM response matches the core identity inf...
# 15  The LLM response directly contradicts the expe...
# 16  The LLM response correctly identifies Food Saf...
# 17  The LLM response correctly communicates that i...
# 18  The LLM response matches the core meaning of E...
# 19  The LLM response correctly conveys the core in...  ,                                                prompt  \
# 0                  List all channels in the workspace
# 1                         Show me all public channels
# 2   Post 'Hello team! From eval framework here.' t...
# 3   Add heart reaction to message at timestamp 175...
# 4   Reply to thread 1750300317.785949 in channel C...
# 5   Get all replies from thread 1750300317.785949 ...
# 6              Show me all the users in the workspace
# 7            Get profile details for user U08FUTB4QLC
# 8         Search for messages containing 'mcp server'
# 9            Get recent messages from the ytg channel
# 10  Post 'Meeting in 5 minutes - from eval framewo...
# 11  Add thumbsup to message 1751349675.278699 in a...
# 12  Reply 'Will be there! from eval framework' to ...
# 13  Show thread replies for 1751349675.278699  in ...
# 14              Get profile details for Mohitha Mohan
# 15  Search for messages containing 'regex' from Os...
# 16            Search for food safari in sydney-office
# 17                 Get profile details for John Smith
# 18  Get me recent messages from the trump-supporte...
# 19                    Search for "petrichor" on slack
#
#                                              model  \
# 0   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 1   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 2   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 3   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 4   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 5   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 6   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 7   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 8   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 9   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 10  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 11  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 12  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 13  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 14  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 15  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 16  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 17  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 18  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 19  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
#
#                                              response  \
# 0   Here's a list of all the channels in the works...
# 1   I've retrieved a list of all public channels i...
# 2   I've posted the message "Hello team! From eval...
# 3   I tried to add a heart reaction to the message...
# 4   I've replied "Thanks for the update!" to the t...
# 5   # Thread Replies in Channel C08UFS9HMCN\n\nI'v...
# 6   # Slack Workspace Users\n\nHere's a list of al...
# 7   # User Profile: Mohitha Mohan\n\n## Basic Info...
# 8   I searched for messages containing 'mcp server...
# 9   I'll get the recent messages from the "ytg" ch...
# 10  I've posted the message "Meeting in 5 minutes ...
# 11  I apologize, but I was unable to add the thumb...
# 12  I've replied to the thread in the ai-slackbot-...
# 13  I'm unable to fetch the thread replies for the...
# 14  # Mohitha Mohan's Profile Details\n\n**Basic I...
# 15  I searched for messages containing 'regex' fro...
# 16  # Food Safari in Sydney Office\n\nBased on the...
# 17  I was not able to find profile details for "Jo...
# 18  I'm sorry, but I couldn't retrieve messages fr...
# 19  I searched for "petrichor" on Slack and found ...
#
#                            selected_expected_response  score answer  \
# 0   Here are all the channels in the Slack workspa...      4    yes
# 1   Here are all the public channels available in ...      3    yes
# 2   I successfully posted the message \Hello team!...      4    yes
# 3   It looks like a heart reaction has already bee...      5    yes
# 4   Perfect! I've successfully replied to the thre...      4    yes
# 5   Here are all the replies in the thread startin...      3    yes
# 6   Here are all the users in your Slack workspace...      4    yes
# 7   Here are the detailed profile information for ...      4    yes
# 8   Here are the search results for messages conta...      4    yes
# 9   I've successfully retrieved the recent message...      2     no
# 10  Perfect! I've successfully posted the message ...      4    yes
# 11                                                NaN      3    yes
# 12  Perfect! I've successfully replied "Will be th...      3    yes
# 13  Here are the thread replies for message 175134...      2     no
# 14  Here are the profile details for Mohitha Mohan...      3    yes
# 15  I found 3 messages from Oscar Fawkes containin...      2     no
# 16  Great! I found 10 messages about "Food Safari"...      3    yes
# 17  It looks like I couldn't find a user with that...      5    yes
# 18  I searched through all the channels in your Sl...      4    yes
# 19  The search for "petrichor" on Slack returned n...      4    yes
#
#                                             reasoning
# 0   The LLM response matches the expected response...
# 1   The LLM response partially matches the expecte...
# 2   The LLM response conveys the same core meaning...
# 3   The LLM response perfectly captures the core m...
# 4   The LLM response conveys the same core meaning...
# 5   The LLM response partially matches the expecte...
# 6   The LLM response closely matches Expected Resp...
# 7   The LLM response contains most of the core pro...
# 8   The LLM response accurately summarizes the 10 ...
# 9   The LLM response accurately retrieves messages...
# 10  The LLM response conveys the same core meaning...
# 11  The LLM response explains an error encountered...
# 12  The LLM response conveys the core action of re...
# 13  The LLM response indicates an inability to acc...
# 14  The LLM response contains some of the same cor...
# 15  The LLM response directly contradicts the expe...
# 16  The LLM response correctly identifies Food Saf...
# 17  The LLM response conveys the same core meaning...
# 18  The LLM response conveys the same core meaning...
# 19  The LLM response correctly communicates the co...  ,                                                prompt  \
# 0                  List all channels in the workspace
# 1                         Show me all public channels
# 2   Post 'Hello team! From eval framework here.' t...
# 3   Add heart reaction to message at timestamp 175...
# 4   Reply to thread 1750300317.785949 in channel C...
# 5   Get all replies from thread 1750300317.785949 ...
# 6              Show me all the users in the workspace
# 7            Get profile details for user U08FUTB4QLC
# 8         Search for messages containing 'mcp server'
# 9            Get recent messages from the ytg channel
# 10  Post 'Meeting in 5 minutes - from eval framewo...
# 11  Add thumbsup to message 1751349675.278699 in a...
# 12  Reply 'Will be there! from eval framework' to ...
# 13  Show thread replies for 1751349675.278699  in ...
# 14              Get profile details for Mohitha Mohan
# 15  Search for messages containing 'regex' from Os...
# 16            Search for food safari in sydney-office
# 17                 Get profile details for John Smith
# 18  Get me recent messages from the trump-supporte...
# 19                    Search for "petrichor" on slack
#
#                                              model  \
# 0   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 1   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 2   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 3   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 4   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 5   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 6   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 7   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 8   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 9   apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 10  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 11  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 12  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 13  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 14  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 15  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 16  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 17  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 18  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 19  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
#
#                                              response  \
# 0   Here's a list of all the channels in the works...
# 1   I've retrieved a list of all public channels i...
# 2   I've posted the message "Hello team! From eval...
# 3   I tried to add a heart reaction to the message...
# 4   I've replied "Thanks for the update!" to the t...
# 5   # Thread Replies in Channel C08UFS9HMCN\n\nI'v...
# 6   # Slack Workspace Users\n\nHere's a list of al...
# 7   # User Profile: Mohitha Mohan\n\n## Basic Info...
# 8   I searched for messages containing 'mcp server...
# 9   I'll get the recent messages from the "ytg" ch...
# 10  I've posted the message "Meeting in 5 minutes ...
# 11  I apologize, but I was unable to add the thumb...
# 12  I've replied to the thread in the ai-slackbot-...
# 13  I'm unable to fetch the thread replies for the...
# 14  # Mohitha Mohan's Profile Details\n\n**Basic I...
# 15  I searched for messages containing 'regex' fro...
# 16  # Food Safari in Sydney Office\n\nBased on the...
# 17  I was not able to find profile details for "Jo...
# 18  I'm sorry, but I couldn't retrieve messages fr...
# 19  I searched for "petrichor" on Slack and found ...
#
#                            selected_expected_response  score answer  \
# 0   Here are all the channels in the Slack workspa...      4    yes
# 1   Here are all the public channels available in ...      3    yes
# 2   I successfully posted the message \Hello team!...      4    yes
# 3   It looks like a heart reaction has already bee...      5    yes
# 4   Perfect! I've successfully replied to the thre...      4    yes
# 5   Here are all the replies in the thread startin...      3    yes
# 6   Here are all the users in your Slack workspace...      4    yes
# 7   Here are the detailed profile information for ...      4    yes
# 8   Here are the search results for messages conta...      4    yes
# 9   I've successfully retrieved the recent message...      2     no
# 10  Perfect! I've successfully posted the message ...      4    yes
# 11                                                NaN      3    yes
# 12  Perfect! I've successfully replied "Will be th...      4    yes
# 13  Here are the thread replies for message 175134...      2     no
# 14  Here are the profile details for Mohitha Mohan...      3    yes
# 15  I found 3 messages from Oscar Fawkes containin...      1     no
# 16  Great! I found 10 messages about "Food Safari"...      4    yes
# 17  It looks like I couldn't find a user with that...      4    yes
# 18  I searched through all the channels in your Sl...      4    yes
# 19  The search for "petrichor" on Slack returned n...      3    yes
#
#                                             reasoning
# 0   The LLM response matches Expected Response 1 b...
# 1   The LLM response partially matches Expected Re...
# 2   The LLM response conveys the same core meaning...
# 3   The LLM response perfectly captures the core m...
# 4   The LLM response conveys the same core action ...
# 5   The LLM response correctly identifies the thre...
# 6   The LLM response provides a comprehensive list...
# 7   The LLM response correctly identifies the core...
# 8   The LLM response accurately summarizes the 10 ...
# 9   Both responses retrieve messages from the ytg ...
# 10  The LLM response correctly states that the mes...
# 11  The LLM response indicates an error occurred w...
# 12  The LLM response conveys the same core action ...
# 13  The LLM response indicates an inability to acc...
# 14  The LLM response provides the core identifying...
# 15  The LLM response directly contradicts the expe...
# 16  The LLM response correctly identifies the core...
# 17  The LLM response conveys the same core meaning...
# 18  The LLM response matches the core meaning of E...
# 19  The LLM response correctly states that the sea...  ]

# %%
# Concatenate all DataFrames
all_data = pd.concat(dfs, ignore_index=True)
print(f"Combined data has {len(all_data)} rows")
print(all_data.head())
# Out:
# Combined data has 60 rows
#                                               prompt  \
# 0                 List all channels in the workspace
# 1                        Show me all public channels
# 2  Post 'Hello team! From eval framework here.' t...
# 3  Add heart reaction to message at timestamp 175...
# 4  Reply to thread 1750300317.785949 in channel C...
#
#                                             model  \
# 0  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 1  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 2  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 3  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
# 4  apac.anthropic.claude-3-7-sonnet-20250219-v1:0
#
#                                             response  \
# 0  Here's a list of all the channels in the works...
# 1  I've retrieved a list of all public channels i...
# 2  I've posted the message "Hello team! From eval...
# 3  I tried to add a heart reaction to the message...
# 4  I've replied "Thanks for the update!" to the t...
#
#                           selected_expected_response  score answer  \
# 0  Here are all the channels in the Slack workspa...      4    yes
# 1  Here are all the public channels available in ...      3    yes
# 2  I successfully posted the message \Hello team!...      4    yes
# 3  It looks like a heart reaction has already bee...      5    yes
# 4  Perfect! I've successfully replied to the thre...      4    yes
#
#                                            reasoning
# 0  The LLM response matches Expected Response 1 v...
# 1  The LLM response partially matches the expecte...
# 2  The LLM response conveys the same core action ...
# 3  The LLM response perfectly captures the core m...
# 4  The LLM response conveys the same core action ...

# %%
print(all_data.columns)
# Out:
# Index(['prompt', 'model', 'response', 'selected_expected_response', 'score',
#        'answer', 'reasoning'],
#       dtype='object')

# %%
# Group by prompt and response, then calculate average scores
grouped = all_data.groupby(['prompt', 'response']).agg({
    'score': 'mean',
}).round(2)
print(grouped)
# Out:
#                                                                                                        score
# prompt                                             response
# Add heart reaction to message at timestamp 1750... I tried to add a heart reaction to the message ...   5.00
# Add thumbsup to message 1751349675.278699 in ai... I apologize, but I was unable to add the thumbs...   3.00
# Get all replies from thread 1750300317.785949 i... # Thread Replies in Channel C08UFS9HMCN\n\nI've...   3.33
# Get me recent messages from the trump-supporter... I'm sorry, but I couldn't retrieve messages fro...   4.00
# Get profile details for John Smith                 I was not able to find profile details for "Joh...   4.33
# Get profile details for Mohitha Mohan              # Mohitha Mohan's Profile Details\n\n**Basic In...   3.00
# Get profile details for user U08FUTB4QLC           # User Profile: Mohitha Mohan\n\n## Basic Infor...   4.00
# Get recent messages from the ytg channel           I'll get the recent messages from the "ytg" cha...   2.00
# List all channels in the workspace                 Here's a list of all the channels in the worksp...   4.00
# Post 'Hello team! From eval framework here.' to... I've posted the message "Hello team! From eval ...   4.00
# Post 'Meeting in 5 minutes - from eval framewor... I've posted the message "Meeting in 5 minutes -...   4.00
# Reply 'Will be there! from eval framework' to t... I've replied to the thread in the ai-slackbot-t...   3.67
# Reply to thread 1750300317.785949 in channel C0... I've replied "Thanks for the update!" to the th...   4.00
# Search for "petrichor" on slack                    I searched for "petrichor" on Slack and found n...   3.33
# Search for food safari in sydney-office            # Food Safari in Sydney Office\n\nBased on the ...   3.33
# Search for messages containing 'mcp server'        I searched for messages containing 'mcp server'...   4.00
# Search for messages containing 'regex' from Osc... I searched for messages containing 'regex' from...   1.67
# Show me all public channels                        I've retrieved a list of all public channels in...   3.00
# Show me all the users in the workspace             # Slack Workspace Users\n\nHere's a list of all...   4.00
# Show thread replies for 1751349675.278699  in a... I'm unable to fetch the thread replies for the ...   2.00

# %%
# Reset index to turn grouped columns back into regular columns
final_results = grouped.reset_index()


print(f"Final results have {len(final_results)} unique prompt-response pairs")
print("\nFirst few rows:")
print(final_results.head())
# Out:
# Final results have 20 unique prompt-response pairs
#
# First few rows:
#                                               prompt  \
# 0  Add heart reaction to message at timestamp 175...
# 1  Add thumbsup to message 1751349675.278699 in a...
# 2  Get all replies from thread 1750300317.785949 ...
# 3  Get me recent messages from the trump-supporte...
# 4                 Get profile details for John Smith
#
#                                             response  score
# 0  I tried to add a heart reaction to the message...   5.00
# 1  I apologize, but I was unable to add the thumb...   3.00
# 2  # Thread Replies in Channel C08UFS9HMCN\n\nI'v...   3.33
# 3  I'm sorry, but I couldn't retrieve messages fr...   4.00
# 4  I was not able to find profile details for "Jo...   4.33

# %%
# Save to final_eval_results.csv
output_path = 'eval_output/final_eval_results.csv'
final_results.to_csv(output_path, index=False)
print(f"\nResults saved to {output_path}")

# Display the results (if using Jupyter)
display(final_results)
# Out:
# Results saved to eval_output/final_eval_results.csv
#                                                prompt  \
# 0   Add heart reaction to message at timestamp 175...
# 1   Add thumbsup to message 1751349675.278699 in a...
# 2   Get all replies from thread 1750300317.785949 ...
# 3   Get me recent messages from the trump-supporte...
# 4                  Get profile details for John Smith
# 5               Get profile details for Mohitha Mohan
# 6            Get profile details for user U08FUTB4QLC
# 7            Get recent messages from the ytg channel
# 8                  List all channels in the workspace
# 9   Post 'Hello team! From eval framework here.' t...
# 10  Post 'Meeting in 5 minutes - from eval framewo...
# 11  Reply 'Will be there! from eval framework' to ...
# 12  Reply to thread 1750300317.785949 in channel C...
# 13                    Search for "petrichor" on slack
# 14            Search for food safari in sydney-office
# 15        Search for messages containing 'mcp server'
# 16  Search for messages containing 'regex' from Os...
# 17                        Show me all public channels
# 18             Show me all the users in the workspace
# 19  Show thread replies for 1751349675.278699  in ...
#
#                                              response  score
# 0   I tried to add a heart reaction to the message...   5.00
# 1   I apologize, but I was unable to add the thumb...   3.00
# 2   # Thread Replies in Channel C08UFS9HMCN\n\nI'v...   3.33
# 3   I'm sorry, but I couldn't retrieve messages fr...   4.00
# 4   I was not able to find profile details for "Jo...   4.33
# 5   # Mohitha Mohan's Profile Details\n\n**Basic I...   3.00
# 6   # User Profile: Mohitha Mohan\n\n## Basic Info...   4.00
# 7   I'll get the recent messages from the "ytg" ch...   2.00
# 8   Here's a list of all the channels in the works...   4.00
# 9   I've posted the message "Hello team! From eval...   4.00
# 10  I've posted the message "Meeting in 5 minutes ...   4.00
# 11  I've replied to the thread in the ai-slackbot-...   3.67
# 12  I've replied "Thanks for the update!" to the t...   4.00
# 13  I searched for "petrichor" on Slack and found ...   3.33
# 14  # Food Safari in Sydney Office\n\nBased on the...   3.33
# 15  I searched for messages containing 'mcp server...   4.00
# 16  I searched for messages containing 'regex' fro...   1.67
# 17  I've retrieved a list of all public channels i...   3.00
# 18  # Slack Workspace Users\n\nHere's a list of al...   4.00
# 19  I'm unable to fetch the thread replies for the...   2.00

# %%
grid = DataGrid(final_results, selection_mode="row", layout={"height": "400px"})
display(grid)
# Out:
# DataGrid(auto_fit_params={'area': 'all', 'padding': 30, 'numCols': None}, corner_renderer=None, default_render…
